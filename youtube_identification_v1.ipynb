# %%
import pandas as pd
import csv 
 
csv.field_size_limit(500 * 1024 * 1024)
 
df=pd.read_csv('./youtube.csv', engine='python')

# %%
df = df.reindex(columns=df.columns.tolist() + ["all_urls", "isKnownLink", "isUTMlink"])

# %%
df.all_urls=None
df.isKnownLink=None
df.isUTMlink=None

# %%
from tqdm import tqdm

# %%
for i in tqdm(range(len(df))):
    all_urls=[]
    all_urls.append(df.loc[i,'url'].strip())
    if df.loc[i,'landing_page']==df.loc[i,'landing_page']:
        all_urls.append(df.loc[i,'landing_page'].strip())
    try:
        records=df.loc[i,'intermediate_urls'].split('\n')
        for record in records:
            if record:
                items=record.split('\t')
                if items[1]:
                    all_urls.append(items[1].strip())
                if items[2]:
                    all_urls.append(items[2].strip())
            all_urls=list(set(all_urls))
            df.at[i, 'all_urls']=all_urls
    except Exception as error:
        all_urls = list(set(all_urls))
        df.at[i, 'all_urls']=all_urls
        pass
# Out:
# 100%|██████████| 57840/57840 [00:04<00:00, 11739.39it/s]

# %%
df
# Out:
#                                                      url  \
# 0                  https://mhzacademy.spayee.com/s/store
# 1                    https://forms.gle/T2eexAjR3ypK9DYW8
# 2          https://mhzacademy.com/cpa-marketing-roadmap/
# 3      http://originalroyalty.com/product/aviyah-drea...
# 4      http://originalroyalty.com/product/solomon-the...
# ...                                                  ...
# 57835                             https://bit.ly/3ya1bDl
# 57836                             https://bit.ly/3ncX5oL
# 57837                             https://bit.ly/3NcsBxz
# 57838                             https://bit.ly/3Ni8IVO
# 57839                             https://bit.ly/3tZNWUp
#
#                                             landing_page  \
# 0                https://mhzacademy.spayee.com/s/store\n
# 1      https://docs.google.com/forms/d/e/1FAIpQLSebPF...
# 2        https://mhzacademy.com/cpa-marketing-roadmap/\n
# 3      https://www.originalroyalty.com/product/aviyah...
# 4      https://www.originalroyalty.com/product/solomo...
# ...                                                  ...
# 57835  https://www.thereformation.com/products/margot...
# 57836  https://bambinifashion.com/gcds/smiley-cherrie...
# 57837  https://coloredorganics.com/collections/organi...
# 57838  https://www.revolve.com/VerifyHuman.jsp?url=%2...
# 57839  https://www.revolve.com/VerifyHuman.jsp?url=%2...
#
#                                        intermediate_urls  \
# 0                                                    NaN
# 1      302\thttps://forms.gle/T2eexAjR3ypK9DYW8\thttp...
# 2      302\thttps://s.adroll.com/j/exp/XR3WQWI67VCVBC...
# 3      302\thttps://c.clarity.ms/c.gif\thttps://c.bin...
# 4                                                    NaN
# ...                                                  ...
# 57835  301\thttps://bit.ly/3ya1bDl\thttps://rstyle.me...
# 57836                                                NaN
# 57837  302\thttps://googleads.g.doubleclick.net/pagea...
# 57838  301\thttps://bit.ly/3Ni8IVO\thttps://rvlv.me/R...
# 57839  301\thttps://bit.ly/3tZNWUp\thttps://rvlv.me/0...
#
#                                                 all_urls isKnownLink isUTMlink
# 0                [https://mhzacademy.spayee.com/s/store]        None      None
# 1      [https://docs.google.com/forms/d/e/1FAIpQLSebP...        None      None
# 2      [https://s.adroll.com/j/exp/XR3WQWI67VCVBCJIOD...        None      None
# 3      [https://c.clarity.ms/c.gif?ctsa=mr&CtsSyncId=...        None      None
# 4      [https://www.originalroyalty.com/product/solom...        None      None
# ...                                                  ...         ...       ...
# 57835  [https://product-gallery.cloudinary.com/1.0.12...        None      None
# 57836  [https://bit.ly/3ncX5oL, https://bambinifashio...        None      None
# 57837  [https://www.google.com/pagead/1p-conversion/1...        None      None
# 57838  [https://www.revolve.com/VerifyHuman.jsp?url=%...        None      None
# 57839  [https://rvlv.me/0OCRVF, https://bit.ly/3tZNWU...        None      None
#
# [57840 rows x 6 columns]

# %%
import re

def url_match_aff(url):
    re_express = re.compile(
        '(ad.admitad.com/g/)|(ad.admitad.com/goto/)|(performance.affiliaxe.com/.*\\?aff_id=)|(performance.affiliaxe.com/.*&aff_id=)|(s.aliexpress.com/.*\\?af=)|(s.aliexpress.com/.*&af=)|(amazon.com/.*\\?tag=)|(amazon.com/.*&tag=)|(amazon.de/.*\\?tag=)|(amazon.de/.*&tag=)|(amazon.it/.*\\?tag=)|(amazon.it/.*&tag=)|(amazon.in/.*\\?tag=)|(amazon.in/.*&tag=)|(amazon.fr/.*\\?tag=)|(amazon.fr/.*&tag=)|(primevideo.com/.*\\?ref=)|(primevideo.com/.*&ref=)|(itunes.apple.com/.*\\?at=)|(itunes.apple.com/.*&at=)|(apple.com/.*\\?afid=)|(apple.com/.*&afid=)|(affiliates.audiobooks.com/.*\\?a_aid=.*&a_bid=)|(affiliates.audiobooks.com/.*\\?a_bid=.*&a_aid=)|(affiliates.audiobooks.com/.*&a_bid=.*&a_aid=)|(avantlink.com/.*\\?pw=)|(avantlink.com/.*&pw=)|(secure.avangate.com/.*\\?affiliate=)|(secure.avangate.com/.*&affiliate=)|(awin1.com/.*\\?awinaffid=)|(awin1.com/.*&awinaffid=)|(ad.zanox.com/ppc^)|(zenaps.com/rclick.php\\?)|(banggood.com/.*\\?p=)|(banggood.com/.*&p=)|(bookdepository.com/.*\\?a_aid=)|(bookdepository.com/.*&a_aid=)|(booking.com/.*\\?aid=)|(booking.com/.*&aid=)|(hop.clickbank.net^)|(anrdoezrs.net/click-)|(cj.dotomi.com^)|(dpbolvw.net/click-)|(emjcd.com^)|(jdoqocy.com/click-)|(kqzyfj.com/click-)|(qksrv.net^)|(tkqlhce.com/click-)|(designmodo.com/\\?u=)|(rover.ebay.com/.*\\?campid=)|(rover.ebay.com/.*&campid=)|(audiojungle.net/.*\\?ref=)|(audiojungle.net/.*&ref=)|(codecanyon.net/.*\\?ref=)|(codecanyon.net/.*&ref=)|(marketplace.envato.com/.*\\?ref=)|(marketplace.envato.com/.*&ref=)|(graphicriver.net/.*\\?ref=)|(graphicriver.net/.*&ref=)|(themeforest.net/.*\\?ref=)|(themeforest.net/.*&ref=)|(videohive.net/.*\\?ref=)|(videohive.net/.*&ref=)|(buyeasy.by/cashback/)|(buyeasy.by/redirect/)|(flipkart.com/.*\\?affid=)|(flipkart.com/.*&affid=)|(gtomegaracing.com/.*\\?tracking=)|(gtomegaracing.com/.*&tracking=)|(search.hotellook.com/.*\\?marker=)|(search.hotellook.com/.*&marker=)|(hotmart.net.br/.*\\?a=)|(hotmart.net.br/.*&a=)|(7eer.net/c/)|(evyy.net/c/)|(kontrolfreek.com/.*\\?a_aid=)|(kontrolfreek.com/.*&a_aid=)|(online.ladbrokes.com/promoRedirect\\?key=)|(online.ladbrokes.com/promoRedirect\\?.*&key=)|(makeupgeek.com/.*\\?acc=)|(makeupgeek.com/.*&acc=)|(gopjn.com/t/)|(pjatr.com/t/)|(pjtra.com/t/)|(pntra.com/t/)|(pntrac.com/t/)|(pntrs.com/t/)|(click.linksynergy.com/.*\\?id=)|(click.linksynergy.com/.*&id=)|(go.redirectingat.com/.*\\?id=)|(go.redirectingat.com/.*&id=)|(olymptrade.com/.*\\?affiliate_id=)|(olymptrade.com/.*&affiliate_id=)|(rstyle.me^)|(shopstyle.it^)|(shareasale.com/r.cfm^)|(shareasale.com/m-pr.cfm^)|(shareasale.com/u.cfm^)|(apessay.com/.*\\?rid=)|(apessay.com/.*&rid=)|(tatacliq.com/.*\\?cid=af:)|(tatacliq.com/.*&cid=af:)|(thermoworks.com/.*\\?tw=)|(thermoworks.com/.*&tw=)|(zaful.com/.*\\?lkid=)|(zaful.com/.*&lkid=)'
    )
    res = re_express.findall(url)
    if res:
        return True
    else:
        return False

def url_match_utm(url):
    re_express = re.compile('((utm_source=.*)|(utm_term=.*)|(utm_campaign=.*)|(utm_content=.*)|(utm_medium=.*)|(aff_id=.*)|(campaignid=.*)){1}')
    res = re_express.findall(url)
    if res:
        return True
    else:
        return False

# %%
for i in tqdm(range(len(df))):
    isKnownLink = []
    isUTMlink = []
    try:
        all_urls = df.loc[i, 'all_urls']
        for url in all_urls:
            if url_match_aff(url):
                isKnownLink.append(url)
            if url_match_utm(url):
                isUTMlink.append(url)
            if isKnownLink:
                df.at[i, 'isKnownLink']=isKnownLink
            if isUTMlink:
                df.at[i, 'isUTMlink']=isUTMlink
    except Exception as error:
        # print(error)
        pass
# Out:
# 100%|██████████| 57840/57840 [03:28<00:00, 277.87it/s]

# %%
df
# Out:
#                                                      url  \
# 0                  https://mhzacademy.spayee.com/s/store
# 1                    https://forms.gle/T2eexAjR3ypK9DYW8
# 2          https://mhzacademy.com/cpa-marketing-roadmap/
# 3      http://originalroyalty.com/product/aviyah-drea...
# 4      http://originalroyalty.com/product/solomon-the...
# ...                                                  ...
# 57835                             https://bit.ly/3ya1bDl
# 57836                             https://bit.ly/3ncX5oL
# 57837                             https://bit.ly/3NcsBxz
# 57838                             https://bit.ly/3Ni8IVO
# 57839                             https://bit.ly/3tZNWUp
#
#                                             landing_page  \
# 0                https://mhzacademy.spayee.com/s/store\n
# 1      https://docs.google.com/forms/d/e/1FAIpQLSebPF...
# 2        https://mhzacademy.com/cpa-marketing-roadmap/\n
# 3      https://www.originalroyalty.com/product/aviyah...
# 4      https://www.originalroyalty.com/product/solomo...
# ...                                                  ...
# 57835  https://www.thereformation.com/products/margot...
# 57836  https://bambinifashion.com/gcds/smiley-cherrie...
# 57837  https://coloredorganics.com/collections/organi...
# 57838  https://www.revolve.com/VerifyHuman.jsp?url=%2...
# 57839  https://www.revolve.com/VerifyHuman.jsp?url=%2...
#
#                                        intermediate_urls  \
# 0                                                    NaN
# 1      302\thttps://forms.gle/T2eexAjR3ypK9DYW8\thttp...
# 2      302\thttps://s.adroll.com/j/exp/XR3WQWI67VCVBC...
# 3      302\thttps://c.clarity.ms/c.gif\thttps://c.bin...
# 4                                                    NaN
# ...                                                  ...
# 57835  301\thttps://bit.ly/3ya1bDl\thttps://rstyle.me...
# 57836                                                NaN
# 57837  302\thttps://googleads.g.doubleclick.net/pagea...
# 57838  301\thttps://bit.ly/3Ni8IVO\thttps://rvlv.me/R...
# 57839  301\thttps://bit.ly/3tZNWUp\thttps://rvlv.me/0...
#
#                                                 all_urls  \
# 0                [https://mhzacademy.spayee.com/s/store]
# 1      [https://docs.google.com/forms/d/e/1FAIpQLSebP...
# 2      [https://s.adroll.com/j/exp/XR3WQWI67VCVBCJIOD...
# 3      [https://c.clarity.ms/c.gif?ctsa=mr&CtsSyncId=...
# 4      [https://www.originalroyalty.com/product/solom...
# ...                                                  ...
# 57835  [https://product-gallery.cloudinary.com/1.0.12...
# 57836  [https://bit.ly/3ncX5oL, https://bambinifashio...
# 57837  [https://www.google.com/pagead/1p-conversion/1...
# 57838  [https://www.revolve.com/VerifyHuman.jsp?url=%...
# 57839  [https://rvlv.me/0OCRVF, https://bit.ly/3tZNWU...
#
#                                              isKnownLink  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 57835  [https://click.linksynergy.com/link?id=QFGLnEo...
# 57836                                               None
# 57837                                               None
# 57838                                               None
# 57839                                               None
#
#                                                isUTMlink
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 57835  [https://www.thereformation.com/products/margo...
# 57836                                               None
# 57837                                               None
# 57838  [https://www.revolve.com/content/deeplink/wome...
# 57839  [https://www.revolve.com/content/deeplink/wome...
#
# [57840 rows x 6 columns]

# %%
df.to_csv('./youtube_after_match_patterns.csv', index=False)

# %%
df_aff=df[~df['isKnownLink'].isna() | ~df['isUTMlink'].isna()]

# %%
df_aff.to_csv('./youtube_aff.csv', index=False)

# %%
df_aff=pd.read_csv('./youtube_aff.csv', engine='python')

# %%
df_aff
# Out:
#                                                      url  \
# 0                                https://amzn.to/3syiwD1
# 1                                https://amzn.to/35SC2Cm
# 2                                https://amzn.to/3HGwdpT
# 3      https://www.amazon.com/gp/product/1119067723/r...
# 4                         http://bit.ly/CareersCloud_App
# ...                                                  ...
# 11372                             https://bit.ly/3tYT2A2
# 11373                             https://bit.ly/3Nl4ZqC
# 11374                             https://bit.ly/3ya1bDl
# 11375                             https://bit.ly/3Ni8IVO
# 11376                             https://bit.ly/3tZNWUp
#
#                                             landing_page  \
# 0      https://www.amazon.in/gp/product/B004XIH3DC/re...
# 1      https://www.amazon.in/gp/product/B07K48339S/re...
# 2      https://www.amazon.in/gp/product/B00Q70JLUM/re...
# 3      https://www.amazon.com/gp/product/1119067723/r...
# 4      https://play.google.com/store/apps/details?id=...
# ...                                                  ...
# 11372  https://www.amazon.com/Echo-Frames/dp/B08T5P7B...
# 11373  https://iamgia.com/products/siobhan-corset-kha...
# 11374  https://www.thereformation.com/products/margot...
# 11375  https://www.revolve.com/VerifyHuman.jsp?url=%2...
# 11376  https://www.revolve.com/VerifyHuman.jsp?url=%2...
#
#                                        intermediate_urls  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4      302\thttps://www.google.com/tools/feedback/cha...
# ...                                                  ...
# 11372  301\thttps://bit.ly/3tYT2A2\thttps://rstyle.me...
# 11373                                                NaN
# 11374  301\thttps://bit.ly/3ya1bDl\thttps://rstyle.me...
# 11375  301\thttps://bit.ly/3Ni8IVO\thttps://rvlv.me/R...
# 11376  301\thttps://bit.ly/3tZNWUp\thttps://rvlv.me/0...
#
#                                                 all_urls  \
# 0      ['https://www.amazon.in/gp/product/B004XIH3DC/...
# 1      ['https://www.amazon.in/gp/product/B07K48339S/...
# 2      ['https://www.amazon.in/gp/product/B00Q70JLUM/...
# 3      ['https://www.amazon.com/gp/product/1119067723...
# 4      ['http://bit.ly/CareersCloud_App', 'https://pl...
# ...                                                  ...
# 11372  ['https://www.amazon.com/Echo-Frames/dp/B08T5P...
# 11373  ['https://bit.ly/3Nl4ZqC', 'https://iamgia.com...
# 11374  ['https://product-gallery.cloudinary.com/1.0.1...
# 11375  ['https://www.revolve.com/VerifyHuman.jsp?url=...
# 11376  ['https://rvlv.me/0OCRVF', 'https://bit.ly/3tZ...
#
#                                              isKnownLink  \
# 0      ['https://www.amazon.in/gp/product/B004XIH3DC/...
# 1      ['https://www.amazon.in/gp/product/B07K48339S/...
# 2      ['https://www.amazon.in/gp/product/B00Q70JLUM/...
# 3      ['https://www.amazon.com/gp/product/1119067723...
# 4                                                    NaN
# ...                                                  ...
# 11372  ['https://www.amazon.com/Echo-Frames/dp/B08T5P...
# 11373                                                NaN
# 11374  ['https://click.linksynergy.com/link?id=QFGLnE...
# 11375                                                NaN
# 11376                                                NaN
#
#                                                isUTMlink
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4      ['https://play.google.com/store/apps/details?i...
# ...                                                  ...
# 11372                                                NaN
# 11373  ['https://iamgia.com/products/siobhan-corset-k...
# 11374  ['https://www.thereformation.com/products/marg...
# 11375  ['https://www.revolve.com/content/deeplink/wom...
# 11376  ['https://www.revolve.com/content/deeplink/wom...
#
# [11377 rows x 6 columns]

# %%
df['isOffer'] = None
df['landing_page_domain']=None

# %%
for i in tqdm(range(len(df))):
    if df.loc[i,'landing_page']==df.loc[i,'landing_page'] and df.loc[i,'landing_page'].startswith('http'):
        df.loc[i,'landing_page_domain']=df.loc[i,'landing_page'].split('/')[2]
# Out:
# 100%|██████████| 57840/57840 [00:05<00:00, 9830.04it/s]

# %%
df
# Out:
#                                                      url  \
# 0                  https://mhzacademy.spayee.com/s/store
# 1                    https://forms.gle/T2eexAjR3ypK9DYW8
# 2          https://mhzacademy.com/cpa-marketing-roadmap/
# 3      http://originalroyalty.com/product/aviyah-drea...
# 4      http://originalroyalty.com/product/solomon-the...
# ...                                                  ...
# 57835                             https://bit.ly/3ya1bDl
# 57836                             https://bit.ly/3ncX5oL
# 57837                             https://bit.ly/3NcsBxz
# 57838                             https://bit.ly/3Ni8IVO
# 57839                             https://bit.ly/3tZNWUp
#
#                                             landing_page  \
# 0                https://mhzacademy.spayee.com/s/store\n
# 1      https://docs.google.com/forms/d/e/1FAIpQLSebPF...
# 2        https://mhzacademy.com/cpa-marketing-roadmap/\n
# 3      https://www.originalroyalty.com/product/aviyah...
# 4      https://www.originalroyalty.com/product/solomo...
# ...                                                  ...
# 57835  https://www.thereformation.com/products/margot...
# 57836  https://bambinifashion.com/gcds/smiley-cherrie...
# 57837  https://coloredorganics.com/collections/organi...
# 57838  https://www.revolve.com/VerifyHuman.jsp?url=%2...
# 57839  https://www.revolve.com/VerifyHuman.jsp?url=%2...
#
#                                        intermediate_urls  \
# 0                                                    NaN
# 1      302\thttps://forms.gle/T2eexAjR3ypK9DYW8\thttp...
# 2      302\thttps://s.adroll.com/j/exp/XR3WQWI67VCVBC...
# 3      302\thttps://c.clarity.ms/c.gif\thttps://c.bin...
# 4                                                    NaN
# ...                                                  ...
# 57835  301\thttps://bit.ly/3ya1bDl\thttps://rstyle.me...
# 57836                                                NaN
# 57837  302\thttps://googleads.g.doubleclick.net/pagea...
# 57838  301\thttps://bit.ly/3Ni8IVO\thttps://rvlv.me/R...
# 57839  301\thttps://bit.ly/3tZNWUp\thttps://rvlv.me/0...
#
#                                                 all_urls  \
# 0                [https://mhzacademy.spayee.com/s/store]
# 1      [https://docs.google.com/forms/d/e/1FAIpQLSebP...
# 2      [https://s.adroll.com/j/exp/XR3WQWI67VCVBCJIOD...
# 3      [https://c.clarity.ms/c.gif?ctsa=mr&CtsSyncId=...
# 4      [https://www.originalroyalty.com/product/solom...
# ...                                                  ...
# 57835  [https://product-gallery.cloudinary.com/1.0.12...
# 57836  [https://bit.ly/3ncX5oL, https://bambinifashio...
# 57837  [https://www.google.com/pagead/1p-conversion/1...
# 57838  [https://www.revolve.com/VerifyHuman.jsp?url=%...
# 57839  [https://rvlv.me/0OCRVF, https://bit.ly/3tZNWU...
#
#                                              isKnownLink  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 57835  [https://click.linksynergy.com/link?id=QFGLnEo...
# 57836                                               None
# 57837                                               None
# 57838                                               None
# 57839                                               None
#
#                                                isUTMlink isOffer  \
# 0                                                   None    None
# 1                                                   None    None
# 2                                                   None    None
# 3                                                   None    None
# 4                                                   None    None
# ...                                                  ...     ...
# 57835  [https://www.thereformation.com/products/margo...    None
# 57836                                               None    None
# 57837                                               None    None
# 57838  [https://www.revolve.com/content/deeplink/wome...    None
# 57839  [https://www.revolve.com/content/deeplink/wome...    None
#
#            landing_page_domain
# 0        mhzacademy.spayee.com
# 1              docs.google.com
# 2               mhzacademy.com
# 3      www.originalroyalty.com
# 4      www.originalroyalty.com
# ...                        ...
# 57835   www.thereformation.com
# 57836       bambinifashion.com
# 57837      coloredorganics.com
# 57838          www.revolve.com
# 57839          www.revolve.com
#
# [57840 rows x 8 columns]

# %%
from sqlalchemy import Column, String, create_engine, Integer
from sqlalchemy.orm import sessionmaker
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.dialects import mysql
from sqlalchemy.sql import and_, asc, desc, or_
from offer_search.model import Offervault_Offer, Affpay_Offer, Odigger_Offer

sqlconn = 'mysql+pymysql://root:1101syw@localhost:3306/youtube_twitter_url?charset=utf8mb4'

# %%
def matchOffer():
    engine = create_engine(sqlconn, echo=False)
    DBSession = sessionmaker(bind=engine)
    session = DBSession()

    unique_domains = df['landing_page_domain'].unique()
    for domain in tqdm(unique_domains):
        if not domain:
            continue
        condition = '%//' + domain + '/%'
        results = {}
        rows = session.query(Offervault_Offer).filter(Offervault_Offer.land_page.like(condition)).all()
        if rows:
            for row in rows:
                results[row.url] = row.land_page
        rows = session.query(Affpay_Offer).filter(Affpay_Offer.land_page.like(condition)).all()
        if rows:
            for row in rows:
                results[row.url] = row.land_page
        rows = session.query(Odigger_Offer).filter(Odigger_Offer.land_page.like(condition)).all()
        if rows:
            for row in rows:
                results[row.url] = row.land_page
        if results:
            # print(results)
            i_list = df.loc[df['landing_page_domain'] == domain].index.to_list()
            for i in i_list:
                df.at[i, 'isOffer'] = results
    session.close()

# %%
matchOffer()
# Out:
# 100%|██████████| 14165/14165 [3:42:40<00:00,  1.06it/s]

# %%
df
# Out:
#                                                      url  \
# 0                  https://mhzacademy.spayee.com/s/store
# 1                    https://forms.gle/T2eexAjR3ypK9DYW8
# 2          https://mhzacademy.com/cpa-marketing-roadmap/
# 3      http://originalroyalty.com/product/aviyah-drea...
# 4      http://originalroyalty.com/product/solomon-the...
# ...                                                  ...
# 57835                             https://bit.ly/3ya1bDl
# 57836                             https://bit.ly/3ncX5oL
# 57837                             https://bit.ly/3NcsBxz
# 57838                             https://bit.ly/3Ni8IVO
# 57839                             https://bit.ly/3tZNWUp
#
#                                             landing_page  \
# 0                https://mhzacademy.spayee.com/s/store\n
# 1      https://docs.google.com/forms/d/e/1FAIpQLSebPF...
# 2        https://mhzacademy.com/cpa-marketing-roadmap/\n
# 3      https://www.originalroyalty.com/product/aviyah...
# 4      https://www.originalroyalty.com/product/solomo...
# ...                                                  ...
# 57835  https://www.thereformation.com/products/margot...
# 57836  https://bambinifashion.com/gcds/smiley-cherrie...
# 57837  https://coloredorganics.com/collections/organi...
# 57838  https://www.revolve.com/VerifyHuman.jsp?url=%2...
# 57839  https://www.revolve.com/VerifyHuman.jsp?url=%2...
#
#                                        intermediate_urls  \
# 0                                                    NaN
# 1      302\thttps://forms.gle/T2eexAjR3ypK9DYW8\thttp...
# 2      302\thttps://s.adroll.com/j/exp/XR3WQWI67VCVBC...
# 3      302\thttps://c.clarity.ms/c.gif\thttps://c.bin...
# 4                                                    NaN
# ...                                                  ...
# 57835  301\thttps://bit.ly/3ya1bDl\thttps://rstyle.me...
# 57836                                                NaN
# 57837  302\thttps://googleads.g.doubleclick.net/pagea...
# 57838  301\thttps://bit.ly/3Ni8IVO\thttps://rvlv.me/R...
# 57839  301\thttps://bit.ly/3tZNWUp\thttps://rvlv.me/0...
#
#                                                 all_urls  \
# 0                [https://mhzacademy.spayee.com/s/store]
# 1      [https://docs.google.com/forms/d/e/1FAIpQLSebP...
# 2      [https://s.adroll.com/j/exp/XR3WQWI67VCVBCJIOD...
# 3      [https://c.clarity.ms/c.gif?ctsa=mr&CtsSyncId=...
# 4      [https://www.originalroyalty.com/product/solom...
# ...                                                  ...
# 57835  [https://product-gallery.cloudinary.com/1.0.12...
# 57836  [https://bit.ly/3ncX5oL, https://bambinifashio...
# 57837  [https://www.google.com/pagead/1p-conversion/1...
# 57838  [https://www.revolve.com/VerifyHuman.jsp?url=%...
# 57839  [https://rvlv.me/0OCRVF, https://bit.ly/3tZNWU...
#
#                                              isKnownLink  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 57835  [https://click.linksynergy.com/link?id=QFGLnEo...
# 57836                                               None
# 57837                                               None
# 57838                                               None
# 57839                                               None
#
#                                                isUTMlink isOffer  \
# 0                                                   None    None
# 1                                                   None    None
# 2                                                   None    None
# 3                                                   None    None
# 4                                                   None    None
# ...                                                  ...     ...
# 57835  [https://www.thereformation.com/products/margo...    None
# 57836                                               None    None
# 57837                                               None    None
# 57838  [https://www.revolve.com/content/deeplink/wome...    None
# 57839  [https://www.revolve.com/content/deeplink/wome...    None
#
#            landing_page_domain
# 0        mhzacademy.spayee.com
# 1              docs.google.com
# 2               mhzacademy.com
# 3      www.originalroyalty.com
# 4      www.originalroyalty.com
# ...                        ...
# 57835   www.thereformation.com
# 57836       bambinifashion.com
# 57837      coloredorganics.com
# 57838          www.revolve.com
# 57839          www.revolve.com
#
# [57840 rows x 8 columns]

# %%
df.to_csv('youtube_results.csv', index=False)

# %%
df.to_feather('youtube_results.feather')
