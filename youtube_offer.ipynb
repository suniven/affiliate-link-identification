# %%
import pandas as pd
import csv

csv.field_size_limit(500 * 1024 * 1024)

df = pd.read_csv('./youtube_all_results.csv', engine='python')

# %%
df
# Out:
#                                                      url  \
# 0                  https://mhzacademy.spayee.com/s/store
# 1                    https://forms.gle/T2eexAjR3ypK9DYW8
# 2          https://mhzacademy.com/cpa-marketing-roadmap/
# 3      http://originalroyalty.com/product/aviyah-drea...
# 4      http://originalroyalty.com/product/solomon-the...
# ...                                                  ...
# 57905                  https://bit.ly/OynaDığıM-BetzMark
# 57906                        https://bit.ly/ASPER_CASINO
# 57907                             https://bit.ly/3wXAr9o
# 57908                             https://bit.ly/2Xgunte
# 57909                https://oportun.com/personal-loans/
#
#                                             landing_page  \
# 0                  https://mhzacademy.spayee.com/s/store
# 1      https://docs.google.com/forms/d/e/1FAIpQLSebPF...
# 2          https://mhzacademy.com/cpa-marketing-roadmap/
# 3      https://www.originalroyalty.com/product/aviyah...
# 4      https://www.originalroyalty.com/product/solomo...
# ...                                                  ...
# 57905                   https://betzmark277.com/tr/games
# 57906                      https://aspercasino620.com/tr
# 57907  https://videoconverter.wondershare.com/?utm_so...
# 57908  https://www.youtube.com/channel/UCSkaixM5p8mYu...
# 57909                https://oportun.com/personal-loans/
#
#                                        intermediate_urls  \
# 0                                                    NaN
# 1      302\thttps://forms.gle/T2eexAjR3ypK9DYW8\thttp...
# 2      302\thttps://s.adroll.com/j/exp/XR3WQWI67VCVBC...
# 3      302\thttps://c.clarity.ms/c.gif\thttps://c.bin...
# 4                                                    NaN
# ...                                                  ...
# 57905  301\thttps://bit.ly/OynaD%C4%B1%C4%9F%C4%B1M-B...
# 57906  301\thttps://bit.ly/ASPER_CASINO\thttp://aspar...
# 57907                                                NaN
# 57908  302\thttps://www.youtube.com/pagead/viewthroug...
# 57909  302\thttps://googleads.g.doubleclick.net/pagea...
#
#                                                 all_urls isKnownLink  \
# 0              ['https://mhzacademy.spayee.com/s/store']         NaN
# 1      ['https://docs.google.com/forms/d/e/1FAIpQLSeb...         NaN
# 2      ['https://s.adroll.com/j/exp/XR3WQWI67VCVBCJIO...         NaN
# 3      ['https://c.clarity.ms/c.gif?ctsa=mr&CtsSyncId...         NaN
# 4      ['https://www.originalroyalty.com/product/solo...         NaN
# ...                                                  ...         ...
# 57905  ['https://gitbtzmrk.com/games/?partner=p3828p9...         NaN
# 57906  ['https://aspercasino620.com/?btag=a_10817b_99...         NaN
# 57907  ['https://bit.ly/3wXAr9o', 'https://videoconve...         NaN
# 57908  ['https://bit.ly/2Xgunte', 'https://www.youtub...         NaN
# 57909  ['https://www.google.com/pagead/1p-conversion/...         NaN
#
#                                                isUTMlink isOffer  \
# 0                                                    NaN     NaN
# 1                                                    NaN     NaN
# 2                                                    NaN     NaN
# 3                                                    NaN     NaN
# 4                                                    NaN     NaN
# ...                                                  ...     ...
# 57905                                                NaN     NaN
# 57906                                                NaN     NaN
# 57907  ['https://videoconverter.wondershare.com/?utm_...     NaN
# 57908                                                NaN     NaN
# 57909                                                NaN     NaN
#
#                   landing_page_domain
# 0               mhzacademy.spayee.com
# 1                     docs.google.com
# 2                      mhzacademy.com
# 3             www.originalroyalty.com
# 4             www.originalroyalty.com
# ...                               ...
# 57905                 betzmark277.com
# 57906              aspercasino620.com
# 57907  videoconverter.wondershare.com
# 57908                 www.youtube.com
# 57909                     oportun.com
#
# [57910 rows x 8 columns]

# %%
df=df[~df['isOffer'].isna()]

# %%
df=df.reset_index(drop=True)

# %%
df
# Out:
#                                                     url  \
# 0                             http://prntscr.com/fbxsj3
# 1     https://www.amazon.com/gp/product/1119067723/r...
# 2                             http://prntscr.com/e4gq95
# 3                               http://www.earnerbd.com
# 4     https://www.amazon.com/gp/gw/ajax/s.html/189-0...
# ...                                                 ...
# 6114                            https://geni.us/38wuAt3
# 6115                            https://geni.us/hOAzH3P
# 6116                              https://geni.us/m2Lop
# 6117  https://www.ebay.com/itm/284632693031?_trkparm...
# 6118  https://www.ebay.com/itm/Car-Phone-Holder-Moun...
#
#                                            landing_page  \
# 0                                https://prnt.sc/fbxsj3
# 1     https://www.amazon.com/gp/product/1119067723/r...
# 2                                https://prnt.sc/e4gq95
# 3     https://www.hugedomains.com/domain_profile.cfm...
# 4     https://www.amazon.com/gp/gw/ajax/s.html/189-0...
# ...                                                 ...
# 6114  https://www.amazon.com/Hub%EF%BC%8CBaseus-Adap...
# 6115  https://www.amazon.com/ANDASEAT-Ergonomic-Comp...
# 6116  https://www.amazon.com/-/es/seguimiento-pantal...
# 6117  https://www.ebay.com/itm/284632693031?_trkparm...
# 6118  https://www.ebay.com/itm/Car-Phone-Holder-Moun...
#
#                                       intermediate_urls  \
# 0     301\thttp://prntscr.com/fbxsj3\thttps://prntsc...
# 1                                                   NaN
# 2     301\thttp://prntscr.com/e4gq95\thttps://prntsc...
# 3     302\thttp://www.earnerbd.com/\thttps://www.hug...
# 4                                                   NaN
# ...                                                 ...
# 6114  302\thttps://geni.us/38wuAt3\thttps://www.amaz...
# 6115  302\thttps://geni.us/hOAzH3P\thttps://www.amaz...
# 6116  302\thttps://geni.us/m2Lop\thttps://www.amazon...
# 6117                                                NaN
# 6118                                                NaN
#
#                                                all_urls  \
# 0     ['https://prntscr.com/fbxsj3', 'https://jp-u.o...
# 1     ['https://www.amazon.com/gp/product/1119067723...
# 2     ['https://an.yandex.ru/mapuid/google/CAESEA3FV...
# 3     ['http://www.earnerbd.com', 'https://www.huged...
# 4     ['https://www.amazon.com/gp/gw/ajax/s.html/189...
# ...                                                 ...
# 6114  ['https://geni.us/38wuAt3', 'https://www.amazo...
# 6115  ['https://www.amazon.com/ANDASEAT-Ergonomic-Co...
# 6116  ['https://geni.us/m2Lop', 'https://aax-fe.amaz...
# 6117  ['https://www.ebay.com/itm/284632693031?_trkpa...
# 6118  ['https://www.ebay.com/itm/Car-Phone-Holder-Mo...
#
#                                             isKnownLink isUTMlink  \
# 0                                                   NaN       NaN
# 1     ['https://www.amazon.com/gp/product/1119067723...       NaN
# 2                                                   NaN       NaN
# 3                                                   NaN       NaN
# 4                                                   NaN       NaN
# ...                                                 ...       ...
# 6114  ['https://www.amazon.com/Hub%EF%BC%8CBaseus-Ad...       NaN
# 6115  ['https://www.amazon.com/ANDASEAT-Ergonomic-Co...       NaN
# 6116  ['https://www.amazon.com/-/es/seguimiento-pant...       NaN
# 6117                                                NaN       NaN
# 6118                                                NaN       NaN
#
#                                                 isOffer  landing_page_domain
# 0     {'https://offervault.com/offer/d0cf875bbbf81c1...              prnt.sc
# 1     {'https://www.affplus.com/o/amazon-shop-for-ho...       www.amazon.com
# 2     {'https://offervault.com/offer/d0cf875bbbf81c1...              prnt.sc
# 3     {'https://www.affplus.com/o/sexy-video-pps-res...  www.hugedomains.com
# 4     {'https://www.affplus.com/o/amazon-shop-for-ho...       www.amazon.com
# ...                                                 ...                  ...
# 6114  {'https://www.affplus.com/o/amazon-shop-for-ho...       www.amazon.com
# 6115  {'https://www.affplus.com/o/amazon-shop-for-ho...       www.amazon.com
# 6116  {'https://www.affplus.com/o/amazon-shop-for-ho...       www.amazon.com
# 6117  {'https://offervault.com/offer/919f9a2a00e0028...         www.ebay.com
# 6118  {'https://offervault.com/offer/919f9a2a00e0028...         www.ebay.com
#
# [6119 rows x 8 columns]

# %%
df['landing_page_domain'].value_counts().head(20)
# Out:
# www.amazon.com         1647
# play.google.com         287
# shopee.co.id            264
# www.tiktok.com          214
# www.google.com          154
# www.udemy.com           154
# apps.apple.com          139
# www.g2a.com             139
# music.apple.com         133
# pages.lazada.com.ph     126
# www.ebay.com            111
# www.linkedin.com        108
# prnt.sc                 108
# www.bluehost.com         99
# www.aliexpress.com       95
# www.fiverr.com           94
# www.skillshare.com       89
# www.edureka.co           77
# www.amazon.co.uk         76
# imgur.com                71
# Name: landing_page_domain, dtype: int64

# %%
df[df['landing_page_domain']=='www.tiktok.com']
# Out:
#                                           url  \
# 51           https://vm.tiktok.com/ZTdxo5yYg/
# 55              https://vm.tiktok.com/E1N1Rs/
# 68    https://www.tiktok.com/@keepmusiclowkey
# 79            https://vm.tiktok.com/ZSsKqj53/
# 80            https://vm.tiktok.com/ZS5Not5N/
# ...                                       ...
# 5502         https://vt.tiktok.com/ZGJSYqLAN/
# 5803        https://www.tiktok.com/@mosballin
# 5924           https://vm.tiktok.com/JF1gDNL/
# 5982  https://www.tiktok.com/@mkb_333?lang=en
# 5986         https://vm.tiktok.com/ZMJATb2CL/
#
#                                            landing_page  \
# 51    https://www.tiktok.com/@chandtyaudits/video/70...
# 55                              https://www.tiktok.com/
# 68              https://www.tiktok.com/@keepmusiclowkey
# 79                              https://www.tiktok.com/
# 80                              https://www.tiktok.com/
# ...                                                 ...
# 5502                            https://www.tiktok.com/
# 5803                  https://www.tiktok.com/@mosballin
# 5924                            https://www.tiktok.com/
# 5982            https://www.tiktok.com/@mkb_333?lang=en
# 5986  https://www.tiktok.com/@thumbz_up_sarah?_d=sec...
#
#                                       intermediate_urls  \
# 51    301\thttps://vm.tiktok.com/ZTdxo5yYg/\thttps:/...
# 55                                                  NaN
# 68                                                  NaN
# 79                                                  NaN
# 80                                                  NaN
# ...                                                 ...
# 5502                                                NaN
# 5803                                                NaN
# 5924                                                NaN
# 5982                                                NaN
# 5986  302\thttps://ad.doubleclick.net/activity;dc_pr...
#
#                                                all_urls isKnownLink  \
# 51    ['https://vm.tiktok.com/ZTdxo5yYg/', 'https://...         NaN
# 55    ['https://www.tiktok.com/', 'https://vm.tiktok...         NaN
# 68          ['https://www.tiktok.com/@keepmusiclowkey']         NaN
# 79    ['https://www.tiktok.com/', 'https://vm.tiktok...         NaN
# 80    ['https://www.tiktok.com/', 'https://vm.tiktok...         NaN
# ...                                                 ...         ...
# 5502  ['https://www.tiktok.com/', 'https://vt.tiktok...         NaN
# 5803              ['https://www.tiktok.com/@mosballin']         NaN
# 5924  ['https://vm.tiktok.com/JF1gDNL/', 'https://ww...         NaN
# 5982        ['https://www.tiktok.com/@mkb_333?lang=en']         NaN
# 5986  ['https://tr.snapchat.com/cm/s?bt=1d53c387&pni...         NaN
#
#                                               isUTMlink  \
# 51                                                  NaN
# 55                                                  NaN
# 68                                                  NaN
# 79                                                  NaN
# 80                                                  NaN
# ...                                                 ...
# 5502                                                NaN
# 5803                                                NaN
# 5924                                                NaN
# 5982                                                NaN
# 5986  ['https://m.tiktok.com/h5/share/usr/6812969222...
#
#                                                 isOffer landing_page_domain
# 51    {'https://www.affplus.com/o/web-mob-dating-sma...      www.tiktok.com
# 55    {'https://www.affplus.com/o/web-mob-dating-sma...      www.tiktok.com
# 68    {'https://www.affplus.com/o/web-mob-dating-sma...      www.tiktok.com
# 79    {'https://www.affplus.com/o/web-mob-dating-sma...      www.tiktok.com
# 80    {'https://www.affplus.com/o/web-mob-dating-sma...      www.tiktok.com
# ...                                                 ...                 ...
# 5502  {'https://www.affplus.com/o/web-mob-dating-sma...      www.tiktok.com
# 5803  {'https://www.affplus.com/o/web-mob-dating-sma...      www.tiktok.com
# 5924  {'https://www.affplus.com/o/web-mob-dating-sma...      www.tiktok.com
# 5982  {'https://www.affplus.com/o/web-mob-dating-sma...      www.tiktok.com
# 5986  {'https://www.affplus.com/o/web-mob-dating-sma...      www.tiktok.com
#
# [214 rows x 8 columns]

# %%
df_offer = pd.DataFrame(columns=['url', 'url_landing_page', 'landing_page_domain','offer_link','offer_landing_page'])

# %%
df_offer
# Out:
# Empty DataFrame
# Columns: [url, url_landing_page, landing_page_domain, offer_link, offer_landing_page]
# Index: []

# %%
df.loc[0, 'isOffer']

# %%
from tqdm import tqdm
import ast
for i in tqdm(range(len(df))):
    url=df.loc[i, 'url']
    url_landing_page = df.loc[i, 'landing_page']
    landing_page_domain = df.loc[i,'landing_page_domain']
    offers = ast.literal_eval(df.loc[i, 'isOffer'])
    for offer_link, offer_landing_page in offers.items():
        item = {
            'url': url,
            'url_landing_page': url_landing_page,
            'landing_page_domain': landing_page_domain,
            'offer_link': offer_link,
            'offer_landing_page': offer_landing_page
        }
        df_offer.loc[len(df_offer)]=item
    # break   # for test
# Out:
#  49%|████▉     | 3000/6119 [10:16:39<10:41:07, 12.33s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\Python\affiliate-link-identification\youtube_offer.ipynb Cell 9 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/d%3A/Python/affiliate-link-identification/youtube_offer.ipynb#X11sZmlsZQ%3D%3D?line=7'>8</a> for offer_link, offer_landing_page in offers.items():
#       <a href='vscode-notebook-cell:/d%3A/Python/affiliate-link-identification/youtube_offer.ipynb#X11sZmlsZQ%3D%3D?line=8'>9</a>     item = {
#      <a href='vscode-notebook-cell:/d%3A/Python/affiliate-link-identification/youtube_offer.ipynb#X11sZmlsZQ%3D%3D?line=9'>10</a>         'url': url,
#      <a href='vscode-notebook-cell:/d%3A/Python/affiliate-link-identification/youtube_offer.ipynb#X11sZmlsZQ%3D%3D?line=10'>11</a>         'url_landing_page': url_landing_page,
#    (...)
#      <a href='vscode-notebook-cell:/d%3A/Python/affiliate-link-identification/youtube_offer.ipynb#X11sZmlsZQ%3D%3D?line=13'>14</a>         'offer_landing_page': offer_landing_page
#      <a href='vscode-notebook-cell:/d%3A/Python/affiliate-link-identification/youtube_offer.ipynb#X11sZmlsZQ%3D%3D?line=14'>15</a>     }
# ---> <a href='vscode-notebook-cell:/d%3A/Python/affiliate-link-identification/youtube_offer.ipynb#X11sZmlsZQ%3D%3D?line=15'>16</a>     df_offer.loc[len(df_offer)]=item
#
# File e:\Anaconda3\envs\py38\lib\site-packages\pandas\core\indexing.py:716, in _LocationIndexer.__setitem__(self, key, value)
#     713 self._has_valid_setitem_indexer(key)
#     715 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 716 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File e:\Anaconda3\envs\py38\lib\site-packages\pandas\core\indexing.py:1682, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1679     indexer, missing = convert_missing_indexer(indexer)
#    1681     if missing:
# -> 1682         self._setitem_with_indexer_missing(indexer, value)
#    1683         return
#    1685 # align and set the values
#
# File e:\Anaconda3\envs\py38\lib\site-packages\pandas\core\indexing.py:2020, in _iLocIndexer._setitem_with_indexer_missing(self, indexer, value)
#    2018     self.obj._mgr = df._mgr
#    2019 else:
# -> 2020     self.obj._mgr = self.obj._append(value)._mgr
#    2021 self.obj._maybe_update_cacher(clear=True)
#
# File e:\Anaconda3\envs\py38\lib\site-packages\pandas\core\frame.py:9082, in DataFrame._append(self, other, ignore_index, verify_integrity, sort)
#    9079 else:
#    9080     to_concat = [self, other]
# -> 9082 result = concat(
#    9083     to_concat,
#    9084     ignore_index=ignore_index,
#    9085     verify_integrity=verify_integrity,
#    9086     sort=sort,
#    9087 )
#    9088 if (
#    9089     combined_columns is not None
#    9090     and not sort
#    (...)
#    9095     # combined_columns.equals check is necessary for preserving dtype
#    9096     #  in test_crosstab_normalize
#    9097     result = result.reindex(combined_columns, axis=1)
#
# File e:\Anaconda3\envs\py38\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File e:\Anaconda3\envs\py38\lib\site-packages\pandas\core\reshape\concat.py:360, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     156 """
#     157 Concatenate pandas objects along a particular axis with optional set logic
#     158 along the other axes.
#    (...)
#     345 ValueError: Indexes have overlapping values: ['a']
#     346 """
#     347 op = _Concatenator(
#     348     objs,
#     349     axis=axis,
#    (...)
#     357     sort=sort,
#     358 )
# --> 360 return op.get_result()
#
# File e:\Anaconda3\envs\py38\lib\site-packages\pandas\core\reshape\concat.py:595, in _Concatenator.get_result(self)
#     591             indexers[ax] = obj_labels.get_indexer(new_labels)
#     593     mgrs_indexers.append((obj._mgr, indexers))
# --> 595 new_data = concatenate_managers(
#     596     mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     597 )
#     598 if not self.copy:
#     599     new_data._consolidate_inplace()
#
# File e:\Anaconda3\envs\py38\lib\site-packages\pandas\core\internals\concat.py:231, in concatenate_managers(mgrs_indexers, axes, concat_axis, copy)
#     225 vals = [ju.block.values for ju in join_units]
#     227 if not blk.is_extension:
#     228     # _is_uniform_join_units ensures a single dtype, so
#     229     #  we can use np.concatenate, which is more performant
#     230     #  than concat_compat
# --> 231     values = np.concatenate(vals, axis=1)
#     232 else:
#     233     # TODO(EA2D): special-casing not needed with 2D EAs
#     234     values = concat_compat(vals, axis=1)
#
# File <__array_function__ internals>:5, in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
df_offer.to_csv('./df_offer_youtube.csv',index=False)
