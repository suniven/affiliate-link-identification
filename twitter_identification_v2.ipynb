# %%
import pandas as pd
import csv
# 最大显示列数
# None代表全部显示,填入数字则显示相应的值
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 1000)
csv.field_size_limit(500 * 1024 * 1024)
# Out:
# 131072

# %%
df = pd.read_csv('./csv/twitter.csv', engine='c')

# %%
df = df.reindex(columns=df.columns.tolist() + [
    "all_urls", "isKnownLink", "knownLinkSource", "isUTMLink", "utm_source", "utm_medium", "utm_campaign", "utm_term",
    "utm_content"
])
df.all_urls = None
df.isKnownLink = None
df.knownLinkSource = None
df.isUTMLink = None
df.utm_source = None
df.utm_medium = None
df.utm_campaign = None
df.utm_term = None
df.utm_content = None

# %%
from tqdm import tqdm
for i in tqdm(range(len(df))):
    all_urls = []
    all_urls.append(df.loc[i, 'url'].strip())
    if df.loc[i, 'landing_page'] == df.loc[i, 'landing_page']:
        all_urls.append(df.loc[i, 'landing_page'].strip())
    try:
        records = df.loc[i, 'intermediate_urls'].split('\n')
        for record in records:
            if record:
                items = record.split('\t')
                if items[1]:
                    all_urls.append(items[1].strip())
                if items[2]:
                    all_urls.append(items[2].strip())
            all_urls = list(set(all_urls))
            df.at[i, 'all_urls'] = all_urls
    except Exception as error:
        all_urls = list(set(all_urls))
        df.at[i, 'all_urls'] = all_urls
        pass
# Out:
# 100%|██████████| 60248/60248 [00:05<00:00, 10246.94it/s]

# %%
import re


def url_match_aff(url):
    re_admitad = re.compile('(ad.admitad.com/g/)|(ad.admitad.com/goto/)')
    res = re_admitad.findall(url)
    if res:
        return True, 'admitad'

    re_affiliaXe = re.compile('(performance.affiliaxe.com/.*\\?aff_id=)|(performance.affiliaxe.com/.*&aff_id=)')
    res = re_affiliaXe.findall(url)
    if res:
        return True, 'affiliaXe'

    re_AliExpress = re.compile('(s.aliexpress.com/.*\\?af=)|(s.aliexpress.com/.*&af=)')
    res = re_AliExpress.findall(url)
    if res:
        return True, 'AliExpress'

    re_Amazon = re.compile(
        '(amazon.com/.*\\?tag=)|(amazon.com/.*&tag=)|(amazon.de/.*\\?tag=)|(amazon.de/.*&tag=)|(amazon.it/.*\\?tag=)|(amazon.it/.*&tag=)|(amazon.in/.*\\?tag=)|(amazon.in/.*&tag=)|(amazon.fr/.*\\?tag=)|(amazon.fr/.*&tag=)'
    )
    res = re_Amazon.findall(url)
    if res:
        return True, 'Amazon'

    re_AmazonPrimeVideo = re.compile('(primevideo.com/.*\\?ref=)|(primevideo.com/.*&ref=)')
    res = re_AmazonPrimeVideo.findall(url)
    if res:
        return True, 'Amazon Prime Video'

    re_Apple = re.compile(
        '(itunes.apple.com/.*\\?at=)|(itunes.apple.com/.*&at=)|(apple.com/.*\\?afid=)|(apple.com/.*&afid=)')
    res = re_Apple.findall(url)
    if res:
        return True, 'Apple'

    re_Audiobooks = re.compile(
        '(affiliates.audiobooks.com/.*\\?a_aid=.*&a_bid=)|(affiliates.audiobooks.com/.*\\?a_bid=.*&a_aid=)|(affiliates.audiobooks.com/.*&a_bid=.*&a_aid=)'
    )
    res = re_Audiobooks.findall(url)
    if res:
        return True, 'Audiobooks'

    re_AvantLink = re.compile('(avantlink.com/.*\\?pw=)|(avantlink.com/.*&pw=)')
    res = re_AvantLink.findall(url)
    if res:
        return True, 'AvantLink'

    re_Avangate = re.compile('(secure.avangate.com/.*\\?affiliate=)|(secure.avangate.com/.*&affiliate=)')
    res = re_Avangate.findall(url)
    if res:
        return True, 'Avangate'

    re_Awin = re.compile(
        '(awin1.com/.*\\?awinaffid=)|(awin1.com/.*&awinaffid=)|(ad.zanox.com/ppc^)|(zenaps.com/rclick.php\\?)')
    res = re_Awin.findall(url)
    if res:
        return True, 'Awin'

    re_Banggood = re.compile('(banggood.com/.*\\?p=)|(banggood.com/.*&p=)')
    res = re_Banggood.findall(url)
    if res:
        return True, 'Banggood'

    re_BookDepository = re.compile('(bookdepository.com/.*\\?a_aid=)|(bookdepository.com/.*&a_aid=)')
    res = re_BookDepository.findall(url)
    if res:
        return True, 'Book Depository'

    re_Bookingcom = re.compile('(booking.com/.*\\?aid=)|(booking.com/.*&aid=)')
    res = re_Bookingcom.findall(url)
    if res:
        return True, 'Booking.com'

    re_Clickbank = re.compile('(hop.clickbank.net^)')
    res = re_Clickbank.findall(url)
    if res:
        return True, 'Clickbank'

    re_CJAffiliate = re.compile(
        '(anrdoezrs.net/click-)|(cj.dotomi.com^)|(dpbolvw.net/click-)|(emjcd.com^)|(jdoqocy.com/click-)|(kqzyfj.com/click-)|(qksrv.net^)|(tkqlhce.com/click-)'
    )
    res = re_CJAffiliate.findall(url)
    if res:
        return True, 'CJ Affiliate'

    re_DesignModo = re.compile('(designmodo.com/\\?u=)')
    res = re_DesignModo.findall(url)
    if res:
        return True, 'DesignModo'

    re_Ebay = re.compile('(rover.ebay.com/.*\\?campid=)|(rover.ebay.com/.*&campid=)')
    res = re_Ebay.findall(url)
    if res:
        return True, 'Ebay'

    re_Envato = re.compile(
        '(audiojungle.net/.*\\?ref=)|(audiojungle.net/.*&ref=)|(codecanyon.net/.*\\?ref=)|(codecanyon.net/.*&ref=)|(marketplace.envato.com/.*\\?ref=)|(marketplace.envato.com/.*&ref=)|(graphicriver.net/.*\\?ref=)|(graphicriver.net/.*&ref=)|(themeforest.net/.*\\?ref=)|(themeforest.net/.*&ref=)|(videohive.net/.*\\?ref=)|(videohive.net/.*&ref=)'
    )
    res = re_Envato.findall(url)
    if res:
        return True, 'Envato'

    re_eCommercePartnersNetwork = re.compile('(buyeasy.by/cashback/)|(buyeasy.by/redirect/)')
    res = re_eCommercePartnersNetwork.findall(url)
    if res:
        return True, 'e-Commerce Partners Network'

    re_Flipkart = re.compile('(flipkart.com/.*\\?affid=)|(flipkart.com/.*&affid=)')
    res = re_Flipkart.findall(url)
    if res:
        return True, 'Flipkart'

    re_GTOmegaRacing = re.compile('(gtomegaracing.com/.*\\?tracking=)|(gtomegaracing.com/.*&tracking=)')
    res = re_GTOmegaRacing.findall(url)
    if res:
        return True, 'GT Omega Racing'

    re_Hotellook = re.compile('(search.hotellook.com/.*\\?marker=)|(search.hotellook.com/.*&marker=)')
    res = re_Hotellook.findall(url)
    if res:
        return True, 'Hotellook'

    re_Hotmart = re.compile('(hotmart.net.br/.*\\?a=)|(hotmart.net.br/.*&a=)')
    res = re_Hotmart.findall(url)
    if res:
        return True, 'Hotmart'

    re_ImpactRadius = re.compile('(7eer.net/c/)|(evyy.net/c/)')
    res = re_ImpactRadius.findall(url)
    if res:
        return True, 'Impact Radius'

    re_KontrolFreek = re.compile('(kontrolfreek.com/.*\\?a_aid=)|(kontrolfreek.com/.*&a_aid=)')
    res = re_KontrolFreek.findall(url)
    if res:
        return True, 'KontrolFreek'

    re_Ladbrokes = re.compile(
        '(online.ladbrokes.com/promoRedirect\\?key=)|(online.ladbrokes.com/promoRedirect\\?.*&key=)')
    res = re_Ladbrokes.findall(url)
    if res:
        return True, 'Ladbrokes'

    re_MakeupGeek = re.compile('(makeupgeek.com/.*\\?acc=)|(makeupgeek.com/.*&acc=)')
    res = re_MakeupGeek.findall(url)
    if res:
        return True, 'Makeup Geek'

    re_PepperjamNetwork = re.compile(
        '(gopjn.com/t/)|(pjatr.com/t/)|(pjtra.com/t/)|(pntra.com/t/)|(pntrac.com/t/)|(pntrs.com/t/)')
    res = re_PepperjamNetwork.findall(url)
    if res:
        return True, 'Pepperjam Network'

    re_RakutenMarketing = re.compile('(click.linksynergy.com/.*\\?id=)|(click.linksynergy.com/.*&id=)')
    res = re_RakutenMarketing.findall(url)
    if res:
        return True, 'Rakuten Marketing'

    re_Skimlinks = re.compile('(go.redirectingat.com/.*\\?id=)|(go.redirectingat.com/.*&id=)')
    res = re_Skimlinks.findall(url)
    if res:
        return True, 'Skimlinks'

    re_Smartex = re.compile('(olymptrade.com/.*\\?affiliate_id=)|(olymptrade.com/.*&affiliate_id=)')
    res = re_Smartex.findall(url)
    if res:
        return True, 'Smartex'

    re_RewardStyle = re.compile('(rstyle.me^)')
    res = re_RewardStyle.findall(url)
    if res:
        return True, 'RewardStyle'

    re_ShopStyle = re.compile('(shopstyle.it^)')
    res = re_ShopStyle.findall(url)
    if res:
        return True, 'ShopStyle'

    re_ShareASale = re.compile('(shareasale.com/r.cfm^)|(shareasale.com/m-pr.cfm^)|(shareasale.com/u.cfm^)')
    res = re_ShareASale.findall(url)
    if res:
        return True, 'ShareASale'

    re_Studybay = re.compile('(apessay.com/.*\\?rid=)|(apessay.com/.*&rid=)')
    res = re_Studybay.findall(url)
    if res:
        return True, 'Studybay'

    re_TataCLiQ = re.compile('(tatacliq.com/.*\\?cid=af:)|(tatacliq.com/.*&cid=af:)')
    res = re_TataCLiQ.findall(url)
    if res:
        return True, 'TataCLiQ'

    re_Thermoworks = re.compile('(thermoworks.com/.*\\?tw=)|(thermoworks.com/.*&tw=)')
    res = re_Thermoworks.findall(url)
    if res:
        return True, 'Thermoworks'

    re_Zaful = re.compile('(zaful.com/.*\\?lkid=)|(zaful.com/.*&lkid=)')
    res = re_Zaful.findall(url)
    if res:
        return True, 'Zaful'

    return False, ''


def url_match_utm_source(url):
    re_express = re.compile('(utm_source=[0-9a-zA-Z-_]*)')
    res = re_express.findall(url)
    if res:
        return res[0][11:]
    return ''


def url_match_utm_medium(url):
    re_express = re.compile('(utm_medium=[0-9a-zA-Z-_]*)')
    res = re_express.findall(url)
    if res:
        return res[0][11:]
    return ''


def url_match_utm_term(url):
    re_express = re.compile('(utm_term=[0-9a-zA-Z-_]*)')
    res = re_express.findall(url)
    if res:
        return res[0][9:]
    return ''


def url_match_utm_campaign(url):
    re_express = re.compile('(utm_campaign=[0-9a-zA-Z-_]*)')
    res = re_express.findall(url)
    if res:
        return res[0][13:]
    return ''


def url_match_utm_content(url):
    re_express = re.compile('(utm_content=[0-9a-zA-Z-_]*)')
    res = re_express.findall(url)
    if res:
        return res[0][12:]
    return ''

# %%
for i in tqdm(range(len(df))):
    isKnownLink = []
    knownLinkSource = []
    isUTMLink = []
    utmSource = []
    utmMedium = []
    utmContent = []
    utmCampaign = []
    utmTerm = []
    try:
        all_urls = df.loc[i, 'all_urls']
        for url in all_urls:
            isKnown, source = url_match_aff(url)
            if isKnown:
                isKnownLink.append(url)
                knownLinkSource.append(source)

            is_utm_source = url_match_utm_source(url)
            is_utm_medium = url_match_utm_medium(url)
            if is_utm_source and is_utm_medium:
                isUTMLink.append(url)
            if is_utm_source:
                utmSource.append(is_utm_source)
            if is_utm_medium:
                utmMedium.append(is_utm_medium)

            is_utm_content = url_match_utm_content(url)
            if is_utm_content:
                utmContent.append(is_utm_content)
            is_utm_campaign = url_match_utm_campaign(url)
            if is_utm_campaign:
                utmCampaign.append(is_utm_campaign)
            is_utm_term = url_match_utm_term(url)
            if is_utm_term:
                utmTerm.append(is_utm_term)


        if isKnownLink:
            df.at[i, 'isKnownLink'] = isKnownLink
            df.at[i, 'knownLinkSource'] = list(set(knownLinkSource))
        if isUTMLink:
            df.at[i, 'isUTMLink'] = isUTMLink
        if utmSource:
            df.at[i, 'utm_source'] = list(set(utmSource))
        if utmMedium:
            df.at[i, 'utm_medium'] = list(set(utmMedium))
        if utmContent:
            df.at[i, 'utm_content'] = list(set(utmContent))
        if utmCampaign:
            df.at[i, 'utm_campaign'] = list(set(utmCampaign))
        if utmTerm:
            df.at[i, 'utm_term'] = list(set(utmTerm))
    except Exception as error:
        # print(error)
        pass
# Out:
# 100%|██████████| 60248/60248 [01:23<00:00, 721.22it/s]

# %%
df
# Out:
#                            url  \
# 0      https://t.co/OdOwqOGVGp
# 1      https://t.co/gwaS83DvJp
# 2      https://t.co/vjCZaCPsqr
# 3      https://t.co/fSDLH4V1RS
# 4      https://t.co/pjKqXYPWyx
# ...                        ...
# 60243  https://t.co/VW0sIarZw9
# 60244  https://t.co/VIeLNNITb6
# 60245  https://t.co/SgQVBjbLgF
# 60246  https://t.co/yU2AKd71Vn
# 60247  https://t.co/f9UOQvCHX1
#
#                                             landing_page  \
# 0      https://madison.com/news/national/griners-mosc...
# 1      https://www.gazettetimes.com/news/national/gri...
# 2      https://herald-review.com/news/national/griner...
# 3      https://wcfcourier.com/news/national/griners-m...
# 4      https://pantagraph.com/news/national/griners-m...
# ...                                                  ...
# 60243  https://watch.dhn.tv/#/shows/DHN_Showcase_Cele...
# 60244  https://www.linkedin.com/posts/irishangel_iris...
# 60245  https://www.herald-dispatch.com/_zapp/tickets-...
# ...

# %%
df.to_csv('./twitter_results_all_v2.csv', index=False)

# %%
df['knownLinkSource'].value_counts()
# Out:
# [Amazon]               2818
# [Rakuten Marketing]      45
# [Awin]                   42
# [CJ Affiliate]           19
# [admitad]                10
# [Flipkart]                8
# [Booking.com]             7
# [Amazon, Awin]            5
# [Banggood]                2
# [Impact Radius]           1
# [Pepperjam Network]       1
# Name: knownLinkSource, dtype: int64

# %%
df[df['url'] == 'https://t.co/ZotUY8rjYw']
# Out:
#                            url  \
# 20377  https://t.co/ZotUY8rjYw
#
#                                             landing_page  \
# 20377  https://www.amazon.in/dp/B08WC9DZ13?tag=degi-21\n
#
#                                        intermediate_urls  \
# 20377  302\thttps://www.mytech.club/cdn/variable_3.gi...
#
#                                                 all_urls  \
# 20377  [https://ad.doubleclick.net/ddm/clk/307647591;...
#
#                                              isKnownLink knownLinkSource  \
# 20377  [https://www.zenaps.com/rclick.php?mid=9773&c_...  [Amazon, Awin]
#
#       isUTMLink utm_source utm_medium utm_campaign utm_term utm_content
# 20377      None       None       None         None     None        None

# %%
df[df['url'] == 'https://t.co/ZotUY8rjYw'].values
# Out:
# array([['https://t.co/ZotUY8rjYw',
#         'https://www.amazon.in/dp/B08WC9DZ13?tag=degi-21\n',
# ...

# %%
import pandas as pd
import csv

csv.field_size_limit(500 * 1024 * 1024)

df = pd.read_csv('./twitter_results_all_v2.csv', engine='python')

# %%
df['isOffer'] = None
df['landing_page_domain'] = None

# %%
df
# Out:
#                            url  \
# 0      https://t.co/OdOwqOGVGp
# 1      https://t.co/gwaS83DvJp
# 2      https://t.co/vjCZaCPsqr
# 3      https://t.co/fSDLH4V1RS
# 4      https://t.co/pjKqXYPWyx
# ...                        ...
# 60243  https://t.co/VW0sIarZw9
# 60244  https://t.co/VIeLNNITb6
# 60245  https://t.co/SgQVBjbLgF
# 60246  https://t.co/yU2AKd71Vn
# 60247  https://t.co/f9UOQvCHX1
#
#                                             landing_page  \
# 0      https://madison.com/news/national/griners-mosc...
# 1      https://www.gazettetimes.com/news/national/gri...
# 2      https://herald-review.com/news/national/griner...
# 3      https://wcfcourier.com/news/national/griners-m...
# 4      https://pantagraph.com/news/national/griners-m...
# ...                                                  ...
# 60243  https://watch.dhn.tv/#/shows/DHN_Showcase_Cele...
# 60244  https://www.linkedin.com/posts/irishangel_iris...
# 60245  https://www.herald-dispatch.com/_zapp/tickets-...
# ...

# %%
from tqdm import tqdm

for i in tqdm(range(len(df))):
    if df.loc[i, 'landing_page'] == df.loc[i, 'landing_page']:
        df.loc[i, 'landing_page']=df.loc[i, 'landing_page'].strip()
# Out:
# 100%|██████████| 60248/60248 [00:08<00:00, 7353.51it/s]

# %%
from tqdm import tqdm

for i in tqdm(range(len(df))):
    if df.loc[i, 'landing_page'] == df.loc[i, 'landing_page'] and df.loc[i, 'landing_page'].startswith('http'):
        df.loc[i, 'landing_page_domain'] = df.loc[i, 'landing_page'].split('/')[2]
# Out:
# 100%|██████████| 60248/60248 [00:43<00:00, 1379.20it/s]

# %%
from sqlalchemy import Column, String, create_engine, Integer
from sqlalchemy.orm import sessionmaker
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.dialects import mysql
from sqlalchemy.sql import and_, asc, desc, or_
from offer_search.model import Offervault_Offer, Affpay_Offer, Odigger_Offer

sqlconn = 'mysql+pymysql://root:1101syw@localhost:3306/youtube_twitter_latest?charset=utf8mb4'

# %%
def matchOffer():
    engine = create_engine(sqlconn, echo=False)
    DBSession = sessionmaker(bind=engine)
    session = DBSession()

    unique_domains = df['landing_page_domain'].unique()
    for domain in tqdm(unique_domains):
        if not domain:
            continue
        condition = '%//' + domain + '/%'
        results = {}
        rows = session.query(Offervault_Offer).filter(Offervault_Offer.land_page.like(condition)).all()
        if rows:
            for row in rows:
                results[row.url] = row.land_page
        rows = session.query(Affpay_Offer).filter(Affpay_Offer.land_page.like(condition)).all()
        if rows:
            for row in rows:
                results[row.url] = row.land_page
        rows = session.query(Odigger_Offer).filter(Odigger_Offer.land_page.like(condition)).all()
        if rows:
            for row in rows:
                results[row.url] = row.land_page
        if results:
            # print(results)
            i_list = df.loc[df['landing_page_domain'] == domain].index.to_list()
            for i in i_list:
                df.at[i, 'isOffer'] = results
    session.close()

# %%
matchOffer()
# Out:
# 100%|██████████| 17590/17590 [1:09:58<00:00,  4.19it/s]

# %%
df
# Out:
#                            url  \
# 0      https://t.co/OdOwqOGVGp
# 1      https://t.co/gwaS83DvJp
# 2      https://t.co/vjCZaCPsqr
# 3      https://t.co/fSDLH4V1RS
# 4      https://t.co/pjKqXYPWyx
# ...                        ...
# 60243  https://t.co/VW0sIarZw9
# 60244  https://t.co/VIeLNNITb6
# 60245  https://t.co/SgQVBjbLgF
# 60246  https://t.co/yU2AKd71Vn
# 60247  https://t.co/f9UOQvCHX1
#
#                                             landing_page  \
# 0      https://madison.com/news/national/griners-mosc...
# 1      https://www.gazettetimes.com/news/national/gri...
# 2      https://herald-review.com/news/national/griner...
# 3      https://wcfcourier.com/news/national/griners-m...
# 4      https://pantagraph.com/news/national/griners-m...
# ...                                                  ...
# 60243  https://watch.dhn.tv/#/shows/DHN_Showcase_Cele...
# 60244  https://www.linkedin.com/posts/irishangel_iris...
# 60245  https://www.herald-dispatch.com/_zapp/tickets-...
# ...

# %%
df.to_csv('./twitter_results_all_v2.csv', index = False)

# %%
df=df[df['isKnownLink'].isna() & df['utm_source'].isna() & df['utm_medium'].isna() & (~df['isOffer'].isna())]

# %%
df
# Out:
#                            url  \
# 10     https://t.co/gWfxYitfO4
# 48     https://t.co/gWupk54TEn
# 55     https://t.co/SHektsoDkj
# 74     https://t.co/cJ86jfgUuu
# 87     https://t.co/LX6OmOsVw1
# ...                        ...
# 60126  https://t.co/O6qlZwfIJH
# 60134  https://t.co/aORCKwxPUj
# 60177  https://t.co/WP8JHlH1FT
# 60178  https://t.co/Bd4QIkkcT9
# 60193  https://t.co/aMn7Nc8awq
#
#                                             landing_page  \
# 10     https://www.usatoday.com/story/sports/wnba/202...
# 48      https://www.simplycook.com/invite/RHMYVK?via=app
# 55     https://www.linkedin.com/pulse/south-african-p...
# 74     https://www.linkedin.com/feed/update/urn:li:sh...
# 87                    https://www.headspace.com/starwars
# ...                                                  ...
# 60126  https://www.amazon.com/gp/product/B07FKT8WRW?r...
# 60134                             https://bit.ly/3IZJutr
# 60177              https://www.amazon.com/dp/1737592630/
# ...

# %%
df=df.reset_index(drop=True)

# %%
df
# Out:
#                           url  \
# 0     https://t.co/gWfxYitfO4
# 1     https://t.co/gWupk54TEn
# 2     https://t.co/SHektsoDkj
# 3     https://t.co/cJ86jfgUuu
# 4     https://t.co/LX6OmOsVw1
# ...                       ...
# 2107  https://t.co/O6qlZwfIJH
# 2108  https://t.co/aORCKwxPUj
# 2109  https://t.co/WP8JHlH1FT
# 2110  https://t.co/Bd4QIkkcT9
# 2111  https://t.co/aMn7Nc8awq
#
#                                            landing_page  \
# 0     https://www.usatoday.com/story/sports/wnba/202...
# 1      https://www.simplycook.com/invite/RHMYVK?via=app
# 2     https://www.linkedin.com/pulse/south-african-p...
# 3     https://www.linkedin.com/feed/update/urn:li:sh...
# 4                    https://www.headspace.com/starwars
# ...                                                 ...
# 2107  https://www.amazon.com/gp/product/B07FKT8WRW?r...
# 2108                             https://bit.ly/3IZJutr
# 2109              https://www.amazon.com/dp/1737592630/
# ...

# %%
df_offer = pd.DataFrame(columns=['url', 'url_landing_page', 'landing_page_domain','offer_link','offer_landing_page'])

# %%
from tqdm import tqdm
import ast
for i in tqdm(range(len(df))):
    url = df.loc[i, 'url']
    url_landing_page = df.loc[i, 'landing_page']
    landing_page_domain = df.loc[i, 'landing_page_domain']
    offers = ast.literal_eval(df.loc[i, 'isOffer'])
    # offers = df.loc[i, 'isOffer']
    for offer_link, offer_landing_page in offers.items():
        item = {
            'url': url,
            'url_landing_page': url_landing_page,
            'landing_page_domain': landing_page_domain,
            'offer_link': offer_link,
            'offer_landing_page': offer_landing_page
        }
        df_offer.loc[len(df_offer)] = item
        break
    # break   # for test
# Out:
# 100%|██████████| 2112/2112 [00:08<00:00, 254.39it/s]

# %%
df_offer.to_csv('./csv/twitter_offer_temp_isna.csv', index=False)

# %%
df_offer
# Out:
#                           url  \
# 0     https://t.co/gWfxYitfO4
# 1     https://t.co/gWupk54TEn
# 2     https://t.co/SHektsoDkj
# 3     https://t.co/cJ86jfgUuu
# 4     https://t.co/LX6OmOsVw1
# ...                       ...
# 2107  https://t.co/O6qlZwfIJH
# 2108  https://t.co/aORCKwxPUj
# 2109  https://t.co/WP8JHlH1FT
# 2110  https://t.co/Bd4QIkkcT9
# 2111  https://t.co/aMn7Nc8awq
#
#                                        url_landing_page landing_page_domain  \
# 0     https://www.usatoday.com/story/sports/wnba/202...    www.usatoday.com
# 1      https://www.simplycook.com/invite/RHMYVK?via=app  www.simplycook.com
# 2     https://www.linkedin.com/pulse/south-african-p...    www.linkedin.com
# 3     https://www.linkedin.com/feed/update/urn:li:sh...    www.linkedin.com
# 4                    https://www.headspace.com/starwars   www.headspace.com
# ...                                                 ...                 ...
# ...

# %%
df_offer.loc[0, 'url_landing_page']
# Out:
# 'https://www.usatoday.com/story/sports/wnba/2022/07/07/brittney-griner-russia-biden-trial-updates/7822327001/?gnt-cfr=1'

# %%
import pandas as pd
import csv

csv.field_size_limit(500 * 1024 * 1024)

df = pd.read_csv('./twitter_results_all_v2.csv', engine='python')

# %%
df
# Out:
#                            url  \
# 0      https://t.co/OdOwqOGVGp
# 1      https://t.co/gwaS83DvJp
# 2      https://t.co/vjCZaCPsqr
# 3      https://t.co/fSDLH4V1RS
# 4      https://t.co/pjKqXYPWyx
# ...                        ...
# 60243  https://t.co/VW0sIarZw9
# 60244  https://t.co/VIeLNNITb6
# 60245  https://t.co/SgQVBjbLgF
# 60246  https://t.co/yU2AKd71Vn
# 60247  https://t.co/f9UOQvCHX1
#
#                                             landing_page  \
# 0      https://madison.com/news/national/griners-mosc...
# 1      https://www.gazettetimes.com/news/national/gri...
# 2      https://herald-review.com/news/national/griner...
# 3      https://wcfcourier.com/news/national/griners-m...
# 4      https://pantagraph.com/news/national/griners-m...
# ...                                                  ...
# 60243  https://watch.dhn.tv/#/shows/DHN_Showcase_Cele...
# 60244  https://www.linkedin.com/posts/irishangel_iris...
# 60245  https://www.herald-dispatch.com/_zapp/tickets-...
# ...

# %%
df.loc[0, 'landing_page']
# Out:
# 'https://madison.com/news/national/griners-moscow-trial-resumes-uks-boris-johnson-to-resign-nadal-weighs-wimbledon-exit/article_90620ee1-4f1a-50de-836b-fe91ff69caaf.html?utm_campaign=snd-autopilot&utm_medium=social&utm_source=twitter_WiStateJournal'

# %%
df.all_urls = None
df.isKnownLink = None
df.knownLinkSource = None
df.isUTMLink = None
df.utm_source = None
df.utm_medium = None
df.utm_campaign = None
df.utm_term = None
df.utm_content = None

# %%
from tqdm import tqdm
for i in tqdm(range(len(df))):
    all_urls = []
    all_urls.append(df.loc[i, 'url'].strip())
    if df.loc[i, 'landing_page'] == df.loc[i, 'landing_page']:
        all_urls.append(df.loc[i, 'landing_page'].strip())
    try:
        records = df.loc[i, 'intermediate_urls'].split('\n')
        for record in records:
            if record:
                items = record.split('\t')
                if items[1]:
                    all_urls.append(items[1].strip())
                if items[2]:
                    all_urls.append(items[2].strip())
            all_urls = list(set(all_urls))
            df.at[i, 'all_urls'] = all_urls
    except Exception as error:
        all_urls = list(set(all_urls))
        df.at[i, 'all_urls'] = all_urls
        pass
# Out:
# 100%|██████████| 60248/60248 [00:05<00:00, 11049.67it/s]

# %%
df = df.reindex(columns=df.columns.tolist() + ['intermediate_url_list', 'redirect_counts'])

# %%
df.intermediate_url_list=None
df.redirect_counts=0

# %%
df
# Out:
#                            url  \
# 0      https://t.co/OdOwqOGVGp
# 1      https://t.co/gwaS83DvJp
# 2      https://t.co/vjCZaCPsqr
# 3      https://t.co/fSDLH4V1RS
# 4      https://t.co/pjKqXYPWyx
# ...                        ...
# 60243  https://t.co/VW0sIarZw9
# 60244  https://t.co/VIeLNNITb6
# 60245  https://t.co/SgQVBjbLgF
# 60246  https://t.co/yU2AKd71Vn
# 60247  https://t.co/f9UOQvCHX1
#
#                                             landing_page  \
# 0      https://madison.com/news/national/griners-mosc...
# 1      https://www.gazettetimes.com/news/national/gri...
# 2      https://herald-review.com/news/national/griner...
# 3      https://wcfcourier.com/news/national/griners-m...
# 4      https://pantagraph.com/news/national/griners-m...
# ...                                                  ...
# 60243  https://watch.dhn.tv/#/shows/DHN_Showcase_Cele...
# 60244  https://www.linkedin.com/posts/irishangel_iris...
# 60245  https://www.herald-dispatch.com/_zapp/tickets-...
# ...

# %%
from tqdm import tqdm
for i in tqdm(range(len(df))):
    middle_urls = []
    begin=df.loc[i, 'url'].strip()
    if df.loc[i, 'landing_page'] == df.loc[i, 'landing_page']:
        end=df.loc[i, 'landing_page'].strip()
    try:
        records = df.loc[i, 'intermediate_urls'].split('\n')
        for record in records:
            if record:
                items = record.split('\t')
                # url
                if items[1] and items[1]!=begin and items[1]!=end:
                    middle_urls.append(items[1].strip())
                # location
                if items[2] and items[2]!=begin and items[2]!=end:
                    middle_urls.append(items[2].strip())
        if middle_urls:
            middle_urls = list(set(middle_urls))
            df.at[i, 'intermediate_url_list'] = middle_urls
            df.loc[i, 'redirect_counts'] = len(middle_urls)
    except Exception as error:
        if middle_urls:
            middle_urls = list(set(middle_urls))
            df.at[i, 'intermediate_url_list'] = middle_urls
            df.loc[i, 'redirect_counts'] = len(middle_urls)
        pass
# Out:
# 100%|██████████| 60248/60248 [00:17<00:00, 3367.35it/s]

# %%
df
# Out:
#                            url  \
# 0      https://t.co/OdOwqOGVGp
# 1      https://t.co/gwaS83DvJp
# 2      https://t.co/vjCZaCPsqr
# 3      https://t.co/fSDLH4V1RS
# 4      https://t.co/pjKqXYPWyx
# ...                        ...
# 60243  https://t.co/VW0sIarZw9
# 60244  https://t.co/VIeLNNITb6
# 60245  https://t.co/SgQVBjbLgF
# 60246  https://t.co/yU2AKd71Vn
# 60247  https://t.co/f9UOQvCHX1
#
#                                             landing_page  \
# 0      https://madison.com/news/national/griners-mosc...
# 1      https://www.gazettetimes.com/news/national/gri...
# 2      https://herald-review.com/news/national/griner...
# 3      https://wcfcourier.com/news/national/griners-m...
# 4      https://pantagraph.com/news/national/griners-m...
# ...                                                  ...
# 60243  https://watch.dhn.tv/#/shows/DHN_Showcase_Cele...
# 60244  https://www.linkedin.com/posts/irishangel_iris...
# 60245  https://www.herald-dispatch.com/_zapp/tickets-...
# ...

# %%
for i in tqdm(range(len(df))):
    isKnownLink = []
    knownLinkSource = []
    isUTMLink = []
    utmSource = []
    utmMedium = []
    utmContent = []
    utmCampaign = []
    utmTerm = []
    try:
        all_urls = df.loc[i, 'all_urls']
        for url in all_urls:
            isKnown, source = url_match_aff(url)
            if isKnown:
                isKnownLink.append(url)
                knownLinkSource.append(source)

            is_utm_source = url_match_utm_source(url)
            is_utm_medium = url_match_utm_medium(url)
            if is_utm_source and is_utm_medium:
                isUTMLink.append(url)
            if is_utm_source:
                utmSource.append(is_utm_source)
            if is_utm_medium:
                utmMedium.append(is_utm_medium)

            is_utm_content = url_match_utm_content(url)
            if is_utm_content:
                utmContent.append(is_utm_content)
            is_utm_campaign = url_match_utm_campaign(url)
            if is_utm_campaign:
                utmCampaign.append(is_utm_campaign)
            is_utm_term = url_match_utm_term(url)
            if is_utm_term:
                utmTerm.append(is_utm_term)


        if isKnownLink:
            df.at[i, 'isKnownLink'] = isKnownLink
            df.at[i, 'knownLinkSource'] = list(set(knownLinkSource))
        if isUTMLink:
            df.at[i, 'isUTMLink'] = isUTMLink
        if utmSource:
            df.at[i, 'utm_source'] = list(set(utmSource))
        if utmMedium:
            df.at[i, 'utm_medium'] = list(set(utmMedium))
        if utmContent:
            df.at[i, 'utm_content'] = list(set(utmContent))
        if utmCampaign:
            df.at[i, 'utm_campaign'] = list(set(utmCampaign))
        if utmTerm:
            df.at[i, 'utm_term'] = list(set(utmTerm))
    except Exception as error:
        # print(error)
        pass
# Out:
# 100%|██████████| 60248/60248 [01:21<00:00, 742.93it/s]

# %%
df
# Out:
#                            url  \
# 0      https://t.co/OdOwqOGVGp
# 1      https://t.co/gwaS83DvJp
# 2      https://t.co/vjCZaCPsqr
# 3      https://t.co/fSDLH4V1RS
# 4      https://t.co/pjKqXYPWyx
# ...                        ...
# 60243  https://t.co/VW0sIarZw9
# 60244  https://t.co/VIeLNNITb6
# 60245  https://t.co/SgQVBjbLgF
# 60246  https://t.co/yU2AKd71Vn
# 60247  https://t.co/f9UOQvCHX1
#
#                                             landing_page  \
# 0      https://madison.com/news/national/griners-mosc...
# 1      https://www.gazettetimes.com/news/national/gri...
# 2      https://herald-review.com/news/national/griner...
# 3      https://wcfcourier.com/news/national/griners-m...
# 4      https://pantagraph.com/news/national/griners-m...
# ...                                                  ...
# 60243  https://watch.dhn.tv/#/shows/DHN_Showcase_Cele...
# 60244  https://www.linkedin.com/posts/irishangel_iris...
# 60245  https://www.herald-dispatch.com/_zapp/tickets-...
# ...

# %%
df.to_csv('./twitter_results_all_v3.csv', index = False)
