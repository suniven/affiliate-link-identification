# %%
import pandas as pd
import csv
# 最大显示列数
# None代表全部显示,填入数字则显示相应的值
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 1000)
csv.field_size_limit(500 * 1024 * 1024)
# Out:
# 131072

# %%
df = pd.read_csv('./csv/youtube_results_all_v3.csv', engine='python')

# %%
df
# Out:
#                                                      url  \
# 0                  https://mhzacademy.spayee.com/s/store
# 1                    https://forms.gle/T2eexAjR3ypK9DYW8
# 2          https://mhzacademy.com/cpa-marketing-roadmap/
# 3      http://originalroyalty.com/product/aviyah-drea...
# 4      http://originalroyalty.com/product/solomon-the...
# ...                                                  ...
# 57835                             https://bit.ly/3ya1bDl
# 57836                             https://bit.ly/3ncX5oL
# 57837                             https://bit.ly/3NcsBxz
# 57838                             https://bit.ly/3Ni8IVO
# 57839                             https://bit.ly/3tZNWUp
#
#                                             landing_page  \
# 0                  https://mhzacademy.spayee.com/s/store
# 1      https://docs.google.com/forms/d/e/1FAIpQLSebPF...
# 2          https://mhzacademy.com/cpa-marketing-roadmap/
# 3      https://www.originalroyalty.com/product/aviyah...
# 4      https://www.originalroyalty.com/product/solomo...
# ...                                                  ...
# 57835  https://www.thereformation.com/products/margot...
# 57836  https://bambinifashion.com/gcds/smiley-cherrie...
# 57837  https://coloredorganics.com/collections/organi...
# 57838  https://www.revolve.com/VerifyHuman.jsp?url=%2...
# 57839  https://www.revolve.com/VerifyHuman.jsp?url=%2...
#
#                                        intermediate_urls  \
# 0                                                    NaN
# 1      302\thttps://forms.gle/T2eexAjR3ypK9DYW8\thttp...
# 2      302\thttps://s.adroll.com/j/exp/XR3WQWI67VCVBC...
# 3      302\thttps://c.clarity.ms/c.gif\thttps://c.bin...
# 4                                                    NaN
# ...                                                  ...
# 57835  301\thttps://bit.ly/3ya1bDl\thttps://rstyle.me...
# 57836                                                NaN
# 57837  302\thttps://googleads.g.doubleclick.net/pagea...
# 57838  301\thttps://bit.ly/3Ni8IVO\thttps://rvlv.me/R...
# 57839  301\thttps://bit.ly/3tZNWUp\thttps://rvlv.me/0...
#
#                                                 all_urls  \
# 0              ['https://mhzacademy.spayee.com/s/store']
# 1      ['https://forms.gle/T2eexAjR3ypK9DYW8', 'https...
# 2      ['https://googleads.g.doubleclick.net/pagead/i...
# 3      ['https://c.clarity.ms/c.gif', 'https://c.bing...
# 4      ['https://www.originalroyalty.com/product/solo...
# ...                                                  ...
# 57835  ['https://rstyle.me/+IQWh4yawR6QIrIhDxb_zjw', ...
# 57836  ['https://bambinifashion.com/gcds/smiley-cherr...
# 57837  ['https://www.google.com.sg/pagead/1p-conversi...
# 57838  ['https://rvlv.me/RCG5Nz', 'https://www.revolv...
# 57839  ['https://bit.ly/3tZNWUp', 'https://www.revolv...
#
#                                              isKnownLink  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 57835  ['https://click.linksynergy.com/link?id=QFGLnE...
# 57836                                                NaN
# 57837                                                NaN
# 57838                                                NaN
# 57839                                                NaN
#
#              knownLinkSource  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 57835  ['Rakuten Marketing']
# 57836                    NaN
# 57837                    NaN
# 57838                    NaN
# 57839                    NaN
#
#                                                isUTMLink          utm_source  \
# 0                                                    NaN                 NaN
# 1                                                    NaN                 NaN
# 2                                                    NaN                 NaN
# 3                                                    NaN                 NaN
# 4                                                    NaN                 NaN
# ...                                                  ...                 ...
# 57835  ['https://www.thereformation.com/products/marg...     ['QFGLnEolOWg']
# 57836                                                NaN                 NaN
# 57837                                                NaN                 NaN
# 57838  ['https://www.revolve.com/content/deeplink/wom...  ['rev_ambassador']
# 57839  ['https://www.revolve.com/content/deeplink/wom...  ['rev_ambassador']
#
#            utm_medium      utm_campaign utm_term utm_content  \
# 0                 NaN               NaN      NaN         NaN
# 1                 NaN               NaN      NaN         NaN
# 2                 NaN               NaN      NaN         NaN
# 3                 NaN               NaN      NaN         NaN
# 4                 NaN               NaN      NaN         NaN
# ...               ...               ...      ...         ...
# 57835          ['15']     ['LinkShare']      NaN         NaN
# 57836             NaN               NaN      NaN         NaN
# 57837             NaN               NaN      NaN         NaN
# 57838  ['ambassador']  ['glob_b_1da01']      NaN         NaN
# 57839  ['ambassador']  ['glob_b_1da01']      NaN         NaN
#
#                                    intermediate_url_list  redirect_counts
# 0                                                    NaN                0
# 1      ['https://docs.google.com/forms/d/e/1FAIpQLSeb...                1
# 2      ['https://googleads.g.doubleclick.net/pagead/i...                4
# 3      ['https://c.bing.com/c.gif?ctsa=mr&CtsSyncId=8...                3
# 4                                                    NaN                0
# ...                                                  ...              ...
# 57835  ['https://rstyle.me/+IQWh4yawR6QIrIhDxb_zjw', ...                4
# 57836                                                NaN                0
# 57837  ['https://www.google.com.sg/pagead/1p-conversi...                6
# 57838  ['https://rvlv.me/RCG5Nz', 'https://www.revolv...                2
# 57839  ['https://www.revolve.com/content/deeplink/wom...                2
#
# [57840 rows x 14 columns]

# %%
df = df.reindex(columns= df.columns.tolist() + ['isOffer'])
df.isOffer = None

# %%
df = df.reindex(columns= df.columns.tolist() + ['landing_page_domain'])
df.landing_page_domain = None

# %%
df
# Out:
#                                                      url  \
# 0                  https://mhzacademy.spayee.com/s/store
# 1                    https://forms.gle/T2eexAjR3ypK9DYW8
# 2          https://mhzacademy.com/cpa-marketing-roadmap/
# 3      http://originalroyalty.com/product/aviyah-drea...
# 4      http://originalroyalty.com/product/solomon-the...
# ...                                                  ...
# 57835                             https://bit.ly/3ya1bDl
# 57836                             https://bit.ly/3ncX5oL
# 57837                             https://bit.ly/3NcsBxz
# 57838                             https://bit.ly/3Ni8IVO
# 57839                             https://bit.ly/3tZNWUp
#
#                                             landing_page  \
# 0                  https://mhzacademy.spayee.com/s/store
# 1      https://docs.google.com/forms/d/e/1FAIpQLSebPF...
# 2          https://mhzacademy.com/cpa-marketing-roadmap/
# 3      https://www.originalroyalty.com/product/aviyah...
# 4      https://www.originalroyalty.com/product/solomo...
# ...                                                  ...
# 57835  https://www.thereformation.com/products/margot...
# 57836  https://bambinifashion.com/gcds/smiley-cherrie...
# 57837  https://coloredorganics.com/collections/organi...
# 57838  https://www.revolve.com/VerifyHuman.jsp?url=%2...
# 57839  https://www.revolve.com/VerifyHuman.jsp?url=%2...
#
#                                        intermediate_urls  \
# 0                                                    NaN
# 1      302\thttps://forms.gle/T2eexAjR3ypK9DYW8\thttp...
# 2      302\thttps://s.adroll.com/j/exp/XR3WQWI67VCVBC...
# 3      302\thttps://c.clarity.ms/c.gif\thttps://c.bin...
# 4                                                    NaN
# ...                                                  ...
# 57835  301\thttps://bit.ly/3ya1bDl\thttps://rstyle.me...
# 57836                                                NaN
# 57837  302\thttps://googleads.g.doubleclick.net/pagea...
# 57838  301\thttps://bit.ly/3Ni8IVO\thttps://rvlv.me/R...
# 57839  301\thttps://bit.ly/3tZNWUp\thttps://rvlv.me/0...
#
#                                                 all_urls  \
# 0              ['https://mhzacademy.spayee.com/s/store']
# 1      ['https://forms.gle/T2eexAjR3ypK9DYW8', 'https...
# 2      ['https://googleads.g.doubleclick.net/pagead/i...
# 3      ['https://c.clarity.ms/c.gif', 'https://c.bing...
# 4      ['https://www.originalroyalty.com/product/solo...
# ...                                                  ...
# 57835  ['https://rstyle.me/+IQWh4yawR6QIrIhDxb_zjw', ...
# 57836  ['https://bambinifashion.com/gcds/smiley-cherr...
# 57837  ['https://www.google.com.sg/pagead/1p-conversi...
# 57838  ['https://rvlv.me/RCG5Nz', 'https://www.revolv...
# 57839  ['https://bit.ly/3tZNWUp', 'https://www.revolv...
#
#                                              isKnownLink  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 57835  ['https://click.linksynergy.com/link?id=QFGLnE...
# 57836                                                NaN
# 57837                                                NaN
# 57838                                                NaN
# 57839                                                NaN
#
#              knownLinkSource  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 57835  ['Rakuten Marketing']
# 57836                    NaN
# 57837                    NaN
# 57838                    NaN
# 57839                    NaN
#
#                                                isUTMLink          utm_source  \
# 0                                                    NaN                 NaN
# 1                                                    NaN                 NaN
# 2                                                    NaN                 NaN
# 3                                                    NaN                 NaN
# 4                                                    NaN                 NaN
# ...                                                  ...                 ...
# 57835  ['https://www.thereformation.com/products/marg...     ['QFGLnEolOWg']
# 57836                                                NaN                 NaN
# 57837                                                NaN                 NaN
# 57838  ['https://www.revolve.com/content/deeplink/wom...  ['rev_ambassador']
# 57839  ['https://www.revolve.com/content/deeplink/wom...  ['rev_ambassador']
#
#            utm_medium      utm_campaign utm_term utm_content  \
# 0                 NaN               NaN      NaN         NaN
# 1                 NaN               NaN      NaN         NaN
# 2                 NaN               NaN      NaN         NaN
# 3                 NaN               NaN      NaN         NaN
# 4                 NaN               NaN      NaN         NaN
# ...               ...               ...      ...         ...
# 57835          ['15']     ['LinkShare']      NaN         NaN
# 57836             NaN               NaN      NaN         NaN
# 57837             NaN               NaN      NaN         NaN
# 57838  ['ambassador']  ['glob_b_1da01']      NaN         NaN
# 57839  ['ambassador']  ['glob_b_1da01']      NaN         NaN
#
#                                    intermediate_url_list  redirect_counts  \
# 0                                                    NaN                0
# 1      ['https://docs.google.com/forms/d/e/1FAIpQLSeb...                1
# 2      ['https://googleads.g.doubleclick.net/pagead/i...                4
# 3      ['https://c.bing.com/c.gif?ctsa=mr&CtsSyncId=8...                3
# 4                                                    NaN                0
# ...                                                  ...              ...
# 57835  ['https://rstyle.me/+IQWh4yawR6QIrIhDxb_zjw', ...                4
# 57836                                                NaN                0
# 57837  ['https://www.google.com.sg/pagead/1p-conversi...                6
# 57838  ['https://rvlv.me/RCG5Nz', 'https://www.revolv...                2
# 57839  ['https://www.revolve.com/content/deeplink/wom...                2
#
#        isAffiliateLink  url_length  landing_page_length isOffer  \
# 0                    0          37                   37    None
# 1                    0          35                   99    None
# 2                    0          45                   45    None
# 3                    0          64                   68    None
# 4                    0          68                   72    None
# ...                ...         ...                  ...     ...
# 57835                1          22                  343    None
# 57836                0          22                  107    None
# 57837                0          22                  146    None
# 57838                1          22                  231    None
# 57839                1          22                  231    None
#
#       landing_page_domain
# 0                    None
# 1                    None
# 2                    None
# 3                    None
# 4                    None
# ...                   ...
# 57835                None
# 57836                None
# 57837                None
# 57838                None
# 57839                None
#
# [57840 rows x 19 columns]

# %%
from tqdm import tqdm

for i in tqdm(range(len(df))):
    if df.loc[i, 'landing_page'] == df.loc[i, 'landing_page'] and df.loc[i, 'landing_page'].startswith('http'):
        df.loc[i, 'landing_page_domain'] = df.loc[i, 'landing_page'].split('/')[2]
# Out:
# 100%|██████████| 57840/57840 [00:38<00:00, 1503.46it/s]

# %%
from sqlalchemy import Column, String, create_engine, Integer
from sqlalchemy.orm import sessionmaker
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.dialects import mysql
from sqlalchemy.sql import and_, asc, desc, or_
from offer_search.model import Offervault_Offer, Affpay_Offer, Odigger_Offer
from tqdm import tqdm

sqlconn = 'mysql+pymysql://root:1101syw@localhost:3306/youtube_twitter_latest?charset=utf8mb4'

# %%
def matchOffer():
    engine = create_engine(sqlconn, echo=False)
    DBSession = sessionmaker(bind=engine)
    session = DBSession()

    unique_domains = df['landing_page_domain'].unique()
    for domain in tqdm(unique_domains):
        if not domain:
            continue
        condition = '%//' + domain + '/%'
        results = {}
        rows = session.query(Offervault_Offer).filter(Offervault_Offer.land_page.like(condition)).all()
        if rows:
            for row in rows:
                results[row.url] = row.land_page
        rows = session.query(Affpay_Offer).filter(Affpay_Offer.land_page.like(condition)).all()
        if rows:
            for row in rows:
                results[row.url] = row.land_page
        rows = session.query(Odigger_Offer).filter(Odigger_Offer.land_page.like(condition)).all()
        if rows:
            for row in rows:
                results[row.url] = row.land_page
        if results:
            # print(results)
            i_list = df.loc[df['landing_page_domain'] == domain].index.to_list()
            for i in i_list:
                df.at[i, 'isOffer'] = results
    session.close()

# %%
matchOffer()
# Out:
# 100%|██████████| 14165/14165 [56:26<00:00,  4.18it/s]

# %%
df
# Out:
#                                                      url  \
# 0                  https://mhzacademy.spayee.com/s/store
# 1                    https://forms.gle/T2eexAjR3ypK9DYW8
# 2          https://mhzacademy.com/cpa-marketing-roadmap/
# 3      http://originalroyalty.com/product/aviyah-drea...
# 4      http://originalroyalty.com/product/solomon-the...
# ...                                                  ...
# 57835                             https://bit.ly/3ya1bDl
# 57836                             https://bit.ly/3ncX5oL
# 57837                             https://bit.ly/3NcsBxz
# 57838                             https://bit.ly/3Ni8IVO
# 57839                             https://bit.ly/3tZNWUp
#
#                                             landing_page  \
# 0                  https://mhzacademy.spayee.com/s/store
# 1      https://docs.google.com/forms/d/e/1FAIpQLSebPF...
# 2          https://mhzacademy.com/cpa-marketing-roadmap/
# 3      https://www.originalroyalty.com/product/aviyah...
# 4      https://www.originalroyalty.com/product/solomo...
# ...                                                  ...
# 57835  https://www.thereformation.com/products/margot...
# 57836  https://bambinifashion.com/gcds/smiley-cherrie...
# 57837  https://coloredorganics.com/collections/organi...
# 57838  https://www.revolve.com/VerifyHuman.jsp?url=%2...
# 57839  https://www.revolve.com/VerifyHuman.jsp?url=%2...
#
#                                        intermediate_urls  \
# 0                                                    NaN
# 1      302\thttps://forms.gle/T2eexAjR3ypK9DYW8\thttp...
# 2      302\thttps://s.adroll.com/j/exp/XR3WQWI67VCVBC...
# 3      302\thttps://c.clarity.ms/c.gif\thttps://c.bin...
# 4                                                    NaN
# ...                                                  ...
# 57835  301\thttps://bit.ly/3ya1bDl\thttps://rstyle.me...
# 57836                                                NaN
# 57837  302\thttps://googleads.g.doubleclick.net/pagea...
# 57838  301\thttps://bit.ly/3Ni8IVO\thttps://rvlv.me/R...
# 57839  301\thttps://bit.ly/3tZNWUp\thttps://rvlv.me/0...
#
#                                                 all_urls  \
# 0              ['https://mhzacademy.spayee.com/s/store']
# 1      ['https://forms.gle/T2eexAjR3ypK9DYW8', 'https...
# 2      ['https://googleads.g.doubleclick.net/pagead/i...
# 3      ['https://c.clarity.ms/c.gif', 'https://c.bing...
# 4      ['https://www.originalroyalty.com/product/solo...
# ...                                                  ...
# 57835  ['https://rstyle.me/+IQWh4yawR6QIrIhDxb_zjw', ...
# 57836  ['https://bambinifashion.com/gcds/smiley-cherr...
# 57837  ['https://www.google.com.sg/pagead/1p-conversi...
# 57838  ['https://rvlv.me/RCG5Nz', 'https://www.revolv...
# 57839  ['https://bit.ly/3tZNWUp', 'https://www.revolv...
#
#                                              isKnownLink  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 57835  ['https://click.linksynergy.com/link?id=QFGLnE...
# 57836                                                NaN
# 57837                                                NaN
# 57838                                                NaN
# 57839                                                NaN
#
#              knownLinkSource  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 57835  ['Rakuten Marketing']
# 57836                    NaN
# 57837                    NaN
# 57838                    NaN
# 57839                    NaN
#
#                                                isUTMLink          utm_source  \
# 0                                                    NaN                 NaN
# 1                                                    NaN                 NaN
# 2                                                    NaN                 NaN
# 3                                                    NaN                 NaN
# 4                                                    NaN                 NaN
# ...                                                  ...                 ...
# 57835  ['https://www.thereformation.com/products/marg...     ['QFGLnEolOWg']
# 57836                                                NaN                 NaN
# 57837                                                NaN                 NaN
# 57838  ['https://www.revolve.com/content/deeplink/wom...  ['rev_ambassador']
# 57839  ['https://www.revolve.com/content/deeplink/wom...  ['rev_ambassador']
#
#            utm_medium      utm_campaign utm_term utm_content  \
# 0                 NaN               NaN      NaN         NaN
# 1                 NaN               NaN      NaN         NaN
# 2                 NaN               NaN      NaN         NaN
# 3                 NaN               NaN      NaN         NaN
# 4                 NaN               NaN      NaN         NaN
# ...               ...               ...      ...         ...
# 57835          ['15']     ['LinkShare']      NaN         NaN
# 57836             NaN               NaN      NaN         NaN
# 57837             NaN               NaN      NaN         NaN
# 57838  ['ambassador']  ['glob_b_1da01']      NaN         NaN
# 57839  ['ambassador']  ['glob_b_1da01']      NaN         NaN
#
#                                    intermediate_url_list  redirect_counts  \
# 0                                                    NaN                0
# 1      ['https://docs.google.com/forms/d/e/1FAIpQLSeb...                1
# 2      ['https://googleads.g.doubleclick.net/pagead/i...                4
# 3      ['https://c.bing.com/c.gif?ctsa=mr&CtsSyncId=8...                3
# 4                                                    NaN                0
# ...                                                  ...              ...
# 57835  ['https://rstyle.me/+IQWh4yawR6QIrIhDxb_zjw', ...                4
# 57836                                                NaN                0
# 57837  ['https://www.google.com.sg/pagead/1p-conversi...                6
# 57838  ['https://rvlv.me/RCG5Nz', 'https://www.revolv...                2
# 57839  ['https://www.revolve.com/content/deeplink/wom...                2
#
#        isAffiliateLink  url_length  landing_page_length isOffer  \
# 0                    0          37                   37    None
# 1                    0          35                   99    None
# 2                    0          45                   45    None
# 3                    0          64                   68    None
# 4                    0          68                   72    None
# ...                ...         ...                  ...     ...
# 57835                1          22                  343    None
# 57836                0          22                  107    None
# 57837                0          22                  146    None
# 57838                1          22                  231    None
# 57839                1          22                  231    None
#
#            landing_page_domain
# 0        mhzacademy.spayee.com
# 1              docs.google.com
# 2               mhzacademy.com
# 3      www.originalroyalty.com
# 4      www.originalroyalty.com
# ...                        ...
# 57835   www.thereformation.com
# 57836       bambinifashion.com
# 57837      coloredorganics.com
# 57838          www.revolve.com
# 57839          www.revolve.com
#
# [57840 rows x 19 columns]

# %%
df[~df['isOffer'].isna()]
# Out:
#                                                      url  \
# 50                             http://prntscr.com/fbxsj3
# 51     https://www.amazon.com/gp/product/1119067723/r...
# 59                             http://prntscr.com/e4gq95
# 61                               http://www.earnerbd.com
# 63     https://www.amazon.com/gp/gw/ajax/s.html/189-0...
# ...                                                  ...
# 57820                             https://bit.ly/3y1Y0gF
# 57821                             https://bit.ly/3bDKpEI
# 57822                             https://bit.ly/3no2sl8
# 57825                             https://bit.ly/3uaZVyg
# 57829                             https://bit.ly/3tYT2A2
#
#                                             landing_page  \
# 50                                https://prnt.sc/fbxsj3
# 51     https://www.amazon.com/gp/product/1119067723/r...
# 59                                https://prnt.sc/e4gq95
# 61     https://www.hugedomains.com/domain_profile.cfm...
# 63     https://www.amazon.com/gp/gw/ajax/s.html/189-0...
# ...                                                  ...
# 57820  https://www.amazon.com/Skip-Hop-Stackable-Cont...
# 57821  https://www.amazon.com/Happy-Organic-Strawberr...
# 57822  https://www.walmart.com/blocked?url=L2lwL0xhcm...
# 57825  https://www.amazon.com/Nana-Loves-More-Jimmy-F...
# 57829  https://www.amazon.com/Echo-Frames/dp/B08T5P7B...
#
#                                        intermediate_urls  \
# 50     301\thttp://prntscr.com/fbxsj3\thttps://prntsc...
# 51                                                   NaN
# 59     301\thttp://prntscr.com/e4gq95\thttps://prntsc...
# 61     302\thttp://www.earnerbd.com/\thttps://www.hug...
# 63                                                   NaN
# ...                                                  ...
# 57820  301\thttps://bit.ly/3y1Y0gF\thttps://rstyle.me...
# 57821  301\thttps://bit.ly/3bDKpEI\thttps://rstyle.me...
# 57822  301\thttps://bit.ly/3no2sl8\thttps://rstyle.me...
# 57825  301\thttps://bit.ly/3uaZVyg\thttps://rstyle.me...
# 57829  301\thttps://bit.ly/3tYT2A2\thttps://rstyle.me...
#
#                                                 all_urls  \
# 50     ['https://jp-u.openx.net/w/1.0/sd?id=537072335...
# 51     ['https://www.amazon.com/gp/product/1119067723...
# 59     ['https://s.amazon-adsystem.com/iu3?cm3ppd=1&d...
# 61     ['http://www.earnerbd.com', 'https://www.huged...
# 63     ['https://www.amazon.com/gp/gw/ajax/s.html/189...
# ...                                                  ...
# 57820  ['https://bit.ly/3y1Y0gF', 'https://www.amazon...
# 57821  ['https://bit.ly/3bDKpEI', 'https://www.amazon...
# 57822  ['https://rstyle.me/+V6-ANdISJa49qIn8B4QZEg', ...
# 57825  ['https://www.amazon.com/Nana-Loves-More-Jimmy...
# 57829  ['https://rstyle.me/+wrpkLdsY831-lvesbApQ2Q', ...
#
#                                              isKnownLink knownLinkSource  \
# 50                                                   NaN             NaN
# 51     ['https://www.amazon.com/gp/product/1119067723...      ['Amazon']
# 59                                                   NaN             NaN
# 61                                                   NaN             NaN
# 63                                                   NaN             NaN
# ...                                                  ...             ...
# 57820  ['https://www.amazon.com/Skip-Hop-Stackable-Co...      ['Amazon']
# 57821  ['https://www.amazon.com/Happy-Organic-Strawbe...      ['Amazon']
# 57822                                                NaN             NaN
# 57825  ['https://www.amazon.com/Nana-Loves-More-Jimmy...      ['Amazon']
# 57829  ['https://www.amazon.com/Echo-Frames/dp/B08T5P...      ['Amazon']
#
#       isUTMLink utm_source utm_medium utm_campaign utm_term utm_content  \
# 50          NaN        NaN        NaN          NaN      NaN         NaN
# 51          NaN        NaN        NaN          NaN      NaN         NaN
# 59          NaN        NaN        NaN          NaN      NaN         NaN
# 61          NaN        NaN        NaN          NaN      NaN         NaN
# 63          NaN        NaN        NaN          NaN      NaN         NaN
# ...         ...        ...        ...          ...      ...         ...
# 57820       NaN        NaN        NaN          NaN      NaN         NaN
# 57821       NaN        NaN        NaN          NaN      NaN         NaN
# 57822       NaN        NaN        NaN          NaN      NaN         NaN
# 57825       NaN        NaN        NaN          NaN      NaN         NaN
# 57829       NaN        NaN        NaN          NaN      NaN         NaN
#
#                                    intermediate_url_list  redirect_counts  \
# 50     ['https://jp-u.openx.net/w/1.0/sd?id=537072335...               45
# 51                                                   NaN                0
# 59     ['https://s.amazon-adsystem.com/iu3?cm3ppd=1&d...               14
# 61                          ['http://www.earnerbd.com/']                1
# 63                                                   NaN                0
# ...                                                  ...              ...
# 57820      ['https://rstyle.me/+W99U5KXKTt4ju-fgqdZ23A']                1
# 57821      ['https://rstyle.me/+40e4lJpv77o0EKG4LLdMvg']                1
# 57822  ['https://rstyle.me/+V6-ANdISJa49qIn8B4QZEg', ...                4
# 57825      ['https://rstyle.me/+Z_GmaKTj3uhvjs6lfYhaXQ']                1
# 57829      ['https://rstyle.me/+wrpkLdsY831-lvesbApQ2Q']                1
#
#        isAffiliateLink  url_length  landing_page_length  \
# 50                   0          25                   22
# 51                   1         142                  142
# 59                   0          25                   22
# 61                   0          23                   61
# 63                   0          61                   61
# ...                ...         ...                  ...
# 57820                1          22                  484
# 57821                1          22                  301
# 57822                0          22                  795
# 57825                1          22                   91
# 57829                1          22                  274
#
#                                                  isOffer  landing_page_domain
# 50     {'https://offervault.com/offer/d0cf875bbbf81c1...              prnt.sc
# 51     {'https://www.affplus.com/o/amazon-shop-for-ho...       www.amazon.com
# 59     {'https://offervault.com/offer/d0cf875bbbf81c1...              prnt.sc
# 61     {'https://www.affplus.com/o/sexy-video-pps-res...  www.hugedomains.com
# 63     {'https://www.affplus.com/o/amazon-shop-for-ho...       www.amazon.com
# ...                                                  ...                  ...
# 57820  {'https://www.affplus.com/o/amazon-shop-for-ho...       www.amazon.com
# 57821  {'https://www.affplus.com/o/amazon-shop-for-ho...       www.amazon.com
# 57822  {'https://offervault.com/offer/e2ec30268b51a0e...      www.walmart.com
# 57825  {'https://www.affplus.com/o/amazon-shop-for-ho...       www.amazon.com
# 57829  {'https://www.affplus.com/o/amazon-shop-for-ho...       www.amazon.com
#
# [6111 rows x 19 columns]

# %%
df.to_csv('./youtube_results.csv', index=False)
