# %%
import pandas as pd
import csv
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 1000)
csv.field_size_limit(500 * 1024 * 1024)
# Out:
# 131072

# %%
df = pd.read_csv('./csv/twitter_results_all_v3.csv', engine='python')

# %%
# 标记affiliate link
df = df.reindex(columns=df.columns.tolist() + ['isAffiliateLink'])
df.isAffiliateLink = 0

# %%
from tqdm import tqdm

for i in tqdm(range(len(df))):
    if df.loc[i, 'isKnownLink'] == df.loc[i, 'isKnownLink']:
        df.loc[i, 'isAffiliateLink'] = 1
        continue
    if df.loc[i, 'isUTMLink'] == df.loc[i, 'isUTMLink']:
        df.loc[i, 'isAffiliateLink'] = 1
        continue
# Out:
# 100%|██████████| 60248/60248 [00:02<00:00, 21249.01it/s]

# %%
df = df.reindex(columns=df.columns.tolist() + ['url_length', 'landing_page_length'])
df.url_length = 0
df.landing_page_length = 0

# %%
for i in tqdm(range(len(df))):
    df.loc[i, 'url_length'] = len(df.loc[i, 'url'])
    if df.loc[i, 'landing_page'] == df.loc[i, 'landing_page']:
        df.loc[i, 'landing_page_length'] = len(df.loc[i, 'landing_page'])
# Out:
# 100%|██████████| 60248/60248 [00:10<00:00, 5998.86it/s]

# %%
df.landing_page_domain=None

# %%
df
# Out:
#                            url  \
# 0      https://t.co/OdOwqOGVGp
# 1      https://t.co/gwaS83DvJp
# 2      https://t.co/vjCZaCPsqr
# 3      https://t.co/fSDLH4V1RS
# 4      https://t.co/pjKqXYPWyx
# ...                        ...
# 60243  https://t.co/VW0sIarZw9
# 60244  https://t.co/VIeLNNITb6
# 60245  https://t.co/SgQVBjbLgF
# 60246  https://t.co/yU2AKd71Vn
# 60247  https://t.co/f9UOQvCHX1
#
#                                             landing_page  \
# 0      https://madison.com/news/national/griners-mosc...
# 1      https://www.gazettetimes.com/news/national/gri...
# 2      https://herald-review.com/news/national/griner...
# 3      https://wcfcourier.com/news/national/griners-m...
# 4      https://pantagraph.com/news/national/griners-m...
# ...                                                  ...
# 60243  https://watch.dhn.tv/#/shows/DHN_Showcase_Cele...
# 60244  https://www.linkedin.com/posts/irishangel_iris...
# 60245  https://www.herald-dispatch.com/_zapp/tickets-...
# 60246  https://www.washington.edu/news/2022/05/27/cri...
# 60247  https://www.ft.com/content/7968cbda-b55d-4303-...
#
#                                        intermediate_urls  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4      302\thttps://bcp.crwdcntrl.net/5/c=6894/rand=6...
# ...                                                  ...
# 60243  301\thttps://bit.ly/3DRcenk\thttps://watch.dhn...
# 60244                                                NaN
# 60245                                                NaN
# 60246  301\thttp://dlvr.it/STmpq8\thttps://www.washin...
# 60247  301\thttp://dlvr.it/STj6XH\thttps://www.ft.com...
#
#                                                 all_urls isKnownLink  \
# 0      ['https://madison.com/news/national/griners-mo...         NaN
# 1      ['https://t.co/gwaS83DvJp', 'https://www.gazet...         NaN
# 2      ['https://t.co/vjCZaCPsqr', 'https://herald-re...         NaN
# 3      ['https://t.co/fSDLH4V1RS', 'https://wcfcourie...         NaN
# 4      ['https://pantagraph.com/news/national/griners...         NaN
# ...                                                  ...         ...
# 60243  ['https://t.co/VW0sIarZw9', 'https://bit.ly/3D...         NaN
# 60244  ['https://www.linkedin.com/posts/irishangel_ir...         NaN
# 60245  ['https://t.co/SgQVBjbLgF', 'https://www.heral...         NaN
# 60246  ['https://www.washington.edu/news/2022/05/27/c...         NaN
# 60247  ['http://dlvr.it/STj6XH', 'https://www.ft.com/...         NaN
#
#       knownLinkSource                                          isUTMLink  \
# 0                 NaN  ['https://madison.com/news/national/griners-mo...
# 1                 NaN  ['https://www.gazettetimes.com/news/national/g...
# 2                 NaN  ['https://herald-review.com/news/national/grin...
# 3                 NaN  ['https://wcfcourier.com/news/national/griners...
# 4                 NaN  ['https://pantagraph.com/news/national/griners...
# ...               ...                                                ...
# 60243             NaN                                                NaN
# 60244             NaN  ['https://www.linkedin.com/posts/irishangel_ir...
# 60245             NaN  ['https://www.herald-dispatch.com/_zapp/ticket...
# 60246             NaN  ['https://www.washington.edu/news/2022/05/27/c...
# 60247             NaN  ['https://www.ft.com/content/7968cbda-b55d-430...
#
#                         utm_source   utm_medium       utm_campaign utm_term  \
# 0       ['twitter_WiStateJournal']   ['social']  ['snd-autopilot']      NaN
# 1               ['twitter_gtnews']   ['social']  ['snd-autopilot']      NaN
# 2      ['twitter_heraldandreview']   ['social']  ['snd-autopilot']      NaN
# 3           ['twitter_wcfcourier']   ['social']  ['snd-autopilot']      NaN
# 4           ['twitter_Pantagraph']   ['social']  ['snd-autopilot']      NaN
# ...                            ...          ...                ...      ...
# 60243                          NaN          NaN                NaN      NaN
# 60244           ['linkedin_share']  ['ios_app']                NaN      NaN
# 60245                  ['twitter']   ['social']           ['blox']      NaN
# 60246                     ['dlvr']  ['twitter']                NaN      NaN
# 60247                     ['dlvr']  ['twitter']                NaN      NaN
#
#       utm_content                                            isOffer  \
# 0             NaN                                                NaN
# 1             NaN                                                NaN
# 2             NaN                                                NaN
# 3             NaN                                                NaN
# 4             NaN                                                NaN
# ...           ...                                                ...
# 60243         NaN                                                NaN
# 60244         NaN  {'https://offervault.com/offer/ea8ff3c8928ca0d...
# 60245         NaN                                                NaN
# 60246         NaN                                                NaN
# 60247         NaN                                                NaN
#
#       landing_page_domain                              intermediate_url_list  \
# 0                    None                                                NaN
# 1                    None                                                NaN
# 2                    None                                                NaN
# 3                    None                                                NaN
# 4                    None  ['https://bcp.crwdcntrl.net/5/c=6894/rand=6287...
# ...                   ...                                                ...
# 60243                None                         ['https://bit.ly/3DRcenk']
# 60244                None                                                NaN
# 60245                None                                                NaN
# 60246                None                          ['http://dlvr.it/STmpq8']
# 60247                None                          ['http://dlvr.it/STj6XH']
#
#        redirect_counts  isAffiliateLink  url_length  landing_page_length
# 0                    0                1          23                  247
# 1                    0                1          23                  248
# 2                    0                1          23                  254
# 3                    0                1          23                  246
# 4                    2                1          23                  246
# ...                ...              ...         ...                  ...
# 60243                1                0          23                   60
# 60244                0                1          23                  168
# 60245                0                1          23                  190
# 60246                1                1          23                  176
# 60247                1                1          23                  101
#
# [60248 rows x 19 columns]

# %%
from tqdm import tqdm

for i in tqdm(range(len(df))):
    if df.loc[i, 'landing_page'] == df.loc[i, 'landing_page'] and df.loc[i, 'landing_page'].startswith('http'):
        df.loc[i, 'landing_page_domain'] = df.loc[i, 'landing_page'].split('/')[2]
# Out:
# 100%|██████████| 60248/60248 [00:06<00:00, 9687.03it/s]

# %%
from sqlalchemy import Column, String, create_engine, Integer
from sqlalchemy.orm import sessionmaker
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.dialects import mysql
from sqlalchemy.sql import and_, asc, desc, or_
from offer_search.model import Offervault_Offer, Affpay_Offer, Odigger_Offer
from tqdm import tqdm

sqlconn = 'mysql+pymysql://root:1101syw@localhost:3306/youtube_twitter_url?charset=utf8mb4'

# %%
def matchOffer():
    engine = create_engine(sqlconn, echo=False)
    DBSession = sessionmaker(bind=engine)
    session = DBSession()

    unique_domains = df['landing_page_domain'].unique()
    for domain in tqdm(unique_domains):
        if not domain:
            continue
        condition = '%//' + domain + '/%'
        results = {}
        rows = session.query(Offervault_Offer).filter(Offervault_Offer.land_page.like(condition)).all()
        if rows:
            for row in rows:
                results[row.url] = row.land_page
        rows = session.query(Affpay_Offer).filter(Affpay_Offer.land_page.like(condition)).all()
        if rows:
            for row in rows:
                results[row.url] = row.land_page
        rows = session.query(Odigger_Offer).filter(Odigger_Offer.land_page.like(condition)).all()
        if rows:
            for row in rows:
                results[row.url] = row.land_page
        if results:
            # print(results)
            i_list = df.loc[df['landing_page_domain'] == domain].index.to_list()
            for i in i_list:
                df.at[i, 'isOffer'] = results
    session.close()

# %%
matchOffer()
# Out:
# 100%|██████████| 17590/17590 [1:45:22<00:00,  2.78it/s]

# %%
df
# Out:
#                            url  \
# 0      https://t.co/OdOwqOGVGp
# 1      https://t.co/gwaS83DvJp
# 2      https://t.co/vjCZaCPsqr
# 3      https://t.co/fSDLH4V1RS
# 4      https://t.co/pjKqXYPWyx
# ...                        ...
# 60243  https://t.co/VW0sIarZw9
# 60244  https://t.co/VIeLNNITb6
# 60245  https://t.co/SgQVBjbLgF
# 60246  https://t.co/yU2AKd71Vn
# 60247  https://t.co/f9UOQvCHX1
#
#                                             landing_page  \
# 0      https://madison.com/news/national/griners-mosc...
# 1      https://www.gazettetimes.com/news/national/gri...
# 2      https://herald-review.com/news/national/griner...
# 3      https://wcfcourier.com/news/national/griners-m...
# 4      https://pantagraph.com/news/national/griners-m...
# ...                                                  ...
# 60243  https://watch.dhn.tv/#/shows/DHN_Showcase_Cele...
# 60244  https://www.linkedin.com/posts/irishangel_iris...
# 60245  https://www.herald-dispatch.com/_zapp/tickets-...
# 60246  https://www.washington.edu/news/2022/05/27/cri...
# 60247  https://www.ft.com/content/7968cbda-b55d-4303-...
#
#                                        intermediate_urls  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4      302\thttps://bcp.crwdcntrl.net/5/c=6894/rand=6...
# ...                                                  ...
# 60243  301\thttps://bit.ly/3DRcenk\thttps://watch.dhn...
# 60244                                                NaN
# 60245                                                NaN
# 60246  301\thttp://dlvr.it/STmpq8\thttps://www.washin...
# 60247  301\thttp://dlvr.it/STj6XH\thttps://www.ft.com...
#
#                                                 all_urls isKnownLink  \
# 0      ['https://madison.com/news/national/griners-mo...         NaN
# 1      ['https://t.co/gwaS83DvJp', 'https://www.gazet...         NaN
# 2      ['https://t.co/vjCZaCPsqr', 'https://herald-re...         NaN
# 3      ['https://t.co/fSDLH4V1RS', 'https://wcfcourie...         NaN
# 4      ['https://pantagraph.com/news/national/griners...         NaN
# ...                                                  ...         ...
# 60243  ['https://t.co/VW0sIarZw9', 'https://bit.ly/3D...         NaN
# 60244  ['https://www.linkedin.com/posts/irishangel_ir...         NaN
# 60245  ['https://t.co/SgQVBjbLgF', 'https://www.heral...         NaN
# 60246  ['https://www.washington.edu/news/2022/05/27/c...         NaN
# 60247  ['http://dlvr.it/STj6XH', 'https://www.ft.com/...         NaN
#
#       knownLinkSource                                          isUTMLink  \
# 0                 NaN  ['https://madison.com/news/national/griners-mo...
# 1                 NaN  ['https://www.gazettetimes.com/news/national/g...
# 2                 NaN  ['https://herald-review.com/news/national/grin...
# 3                 NaN  ['https://wcfcourier.com/news/national/griners...
# 4                 NaN  ['https://pantagraph.com/news/national/griners...
# ...               ...                                                ...
# 60243             NaN                                                NaN
# 60244             NaN  ['https://www.linkedin.com/posts/irishangel_ir...
# 60245             NaN  ['https://www.herald-dispatch.com/_zapp/ticket...
# 60246             NaN  ['https://www.washington.edu/news/2022/05/27/c...
# 60247             NaN  ['https://www.ft.com/content/7968cbda-b55d-430...
#
#                         utm_source   utm_medium       utm_campaign utm_term  \
# 0       ['twitter_WiStateJournal']   ['social']  ['snd-autopilot']      NaN
# 1               ['twitter_gtnews']   ['social']  ['snd-autopilot']      NaN
# 2      ['twitter_heraldandreview']   ['social']  ['snd-autopilot']      NaN
# 3           ['twitter_wcfcourier']   ['social']  ['snd-autopilot']      NaN
# 4           ['twitter_Pantagraph']   ['social']  ['snd-autopilot']      NaN
# ...                            ...          ...                ...      ...
# 60243                          NaN          NaN                NaN      NaN
# 60244           ['linkedin_share']  ['ios_app']                NaN      NaN
# 60245                  ['twitter']   ['social']           ['blox']      NaN
# 60246                     ['dlvr']  ['twitter']                NaN      NaN
# 60247                     ['dlvr']  ['twitter']                NaN      NaN
#
#       utm_content                                            isOffer  \
# 0             NaN                                                NaN
# 1             NaN                                                NaN
# 2             NaN                                                NaN
# 3             NaN                                                NaN
# 4             NaN                                                NaN
# ...           ...                                                ...
# 60243         NaN                                                NaN
# 60244         NaN  {'https://offervault.com/offer/ea8ff3c8928ca0d...
# 60245         NaN                                                NaN
# 60246         NaN                                                NaN
# 60247         NaN                                                NaN
#
#            landing_page_domain  \
# 0                  madison.com
# 1         www.gazettetimes.com
# 2            herald-review.com
# 3               wcfcourier.com
# 4               pantagraph.com
# ...                        ...
# 60243             watch.dhn.tv
# 60244         www.linkedin.com
# 60245  www.herald-dispatch.com
# 60246       www.washington.edu
# 60247               www.ft.com
#
#                                    intermediate_url_list  redirect_counts  \
# 0                                                    NaN                0
# 1                                                    NaN                0
# 2                                                    NaN                0
# 3                                                    NaN                0
# 4      ['https://bcp.crwdcntrl.net/5/c=6894/rand=6287...                2
# ...                                                  ...              ...
# 60243                         ['https://bit.ly/3DRcenk']                1
# 60244                                                NaN                0
# 60245                                                NaN                0
# 60246                          ['http://dlvr.it/STmpq8']                1
# 60247                          ['http://dlvr.it/STj6XH']                1
#
#        isAffiliateLink  url_length  landing_page_length
# 0                    1          23                  247
# 1                    1          23                  248
# 2                    1          23                  254
# 3                    1          23                  246
# 4                    1          23                  246
# ...                ...         ...                  ...
# 60243                0          23                   60
# 60244                1          23                  168
# 60245                1          23                  190
# 60246                1          23                  176
# 60247                1          23                  101
#
# [60248 rows x 19 columns]

# %%
df.to_csv('./twitter_results.csv', index = False)
