# %%
import pandas as pd
import csv
# 最大显示列数
# None代表全部显示,填入数字则显示相应的值
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 1000)
csv.field_size_limit(500 * 1024 * 1024)
# Out:
# 131072

# %%
df = pd.read_csv('./twitter_results_all_v3.csv', engine='python')
