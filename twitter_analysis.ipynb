# %%
import pandas as pd
import csv

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 50)
csv.field_size_limit(500 * 1024 * 1024)
# Out:
# 131072

# %%
df = pd.read_csv('./twitter_results.csv', engine='python')

# %%
df[df['isAffiliateLink'] == 1].redirect_counts.mean()
# Out:
# 5.46107615738567

# %%
df[df['isAffiliateLink'] == 0].redirect_counts.mean()
# Out:
# 5.1079457247121915

# %%
df[df['isAffiliateLink'] == 1].url_length.mean()
# Out:
# 23.0

# %%
df[df['isAffiliateLink'] == 1].landing_page_length.mean()
# Out:
# 150.8167903089492

# %%
df[df['isAffiliateLink'] == 0].url_length.mean()
# Out:
# 23.0

# %%
df[df['isAffiliateLink'] == 0].landing_page_length.mean()
# Out:
# 87.38397951571605

# %%
df.columns
# Out:
# Index(['url', 'landing_page', 'intermediate_urls', 'all_urls', 'isKnownLink',
#        'knownLinkSource', 'isUTMLink', 'utm_source', 'utm_medium',
#        'utm_campaign', 'utm_term', 'utm_content', 'isOffer',
#        'landing_page_domain', 'intermediate_url_list', 'redirect_counts',
#        'isAffiliateLink', 'url_length', 'landing_page_length'],
#       dtype='object')
